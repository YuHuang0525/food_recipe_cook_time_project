# %%
import gzip
from collections import defaultdict
from sklearn import linear_model
import csv

# %%
import random

# %%
def readCSV(path):
    f = gzip.open(path, 'rt')
    c = csv.reader(f)
    header = next(c)
    for l in c:
        d = dict(zip(header,l))
        yield d['user_id'],d['recipe_id'],d

# %%
dataset = list(readCSV("trainInteractions.csv.gz"))

# %% [markdown]
# Split data into training and validation set

# %%
train = dataset[:400000]
valid = dataset[400000:]

# %%
len(dataset)
# Out:
# 500000

# %%
# create the dict to store all the recipes that each user has cooked previously
recipesPerUser = defaultdict(set)
for data in dataset:
    recipesPerUser[data[0]].add(data[1])

# %%
revised_valid = []
for data in valid:
    revised_valid.append((data[0],data[1]))

# %%
recipeCount = defaultdict(int)
totalCooked = 0

for user,recipe,_ in dataset:
    recipeCount[recipe] += 1
    totalCooked += 1

# %%
len(valid)
# Out:
# 100000

# %%
revised_valid = valid.copy()

# %%
# randomly select from all recipes and check whether it's cooked by that user, then create a negative pair 
# and append to the revised valid set

for data in valid:
    cooked = True
    while cooked:
        random_entry = random.sample(recipeCount.keys(),1)
        if random_entry[0] not in recipesPerUser[data[0]]:
            if (data[0],random_entry[0]) not in revised_valid:
                revised_valid.append((data[0],random_entry[0]))
                cooked = False

# %%
# now we have the revised_valid, where the top 100000 data is cooked and the rest is not cooked by each corresponding user
revised_valid_tuples = []
for x in range(100000):
    revised_valid_tuples.append((revised_valid[x][0], revised_valid[x][1]))

for x in range(100000, len(revised_valid)):
    revised_valid_tuples.append(revised_valid[x])

# %%
len(set(revised_valid_tuples))
# Out:
# 200000

# %%
# %store revised_valid_tuples
# %store revised_valid
# Out:
# Stored 'revised_valid_tuples' (list)
# Stored 'revised_valid' (list)

# %%
# %store -r revised_valid_tuples
# %store -r revised_valid

# %%
# sort the recipe based on popularity
recipeCount = defaultdict(int)
totalCooked = 0

for user,recipe,_ in dataset:
    recipeCount[recipe] += 1
    totalCooked += 1

mostPopular = [(recipeCount[x], x) for x in recipeCount]
mostPopular.sort()
mostPopular.reverse()

# %%
def mostPopular_nth(n):
    return1 = set()
    count = 0
    for ic, i in mostPopular:
        count += ic
        return1.add(i)
        if count > (totalCooked * n): break
    return return1

# %%
# find the recipesPerUser and usersPerRecipe of the training set
recipesPerUser = defaultdict(set)
usersPerRecipe = defaultdict(set)

for data in dataset:
    recipesPerUser[data[0]].add(data[1])
    usersPerRecipe[data[1]].add(data[0])

# %%
def Jaccard(s1,s2):
    inter = s1.intersection(s2)
    union = s1.union(s2)
    if len(union) == 0:
        return 0
    else:
        return len(inter) / len(union)

# %%
# here we define a function that represents the model by applying popularity check and similarity check, 
# i is the threshold of the Jaccard similarity score, 
# j is the threshold of the popularity threshold,
# and returns the prediction from the model upon the test_data_set.

def cooking_model(data_set,i,j):
    # first find the top popular recipes
    top_popular = mostPopular_nth(j)
    
    predicts = []
    for data in data_set:
        user = data[0]
        recipe = data[1]
        
        if len(recipesPerUser[user]) == 0:
            predicts.append(0)
        else:
            condition_met = False
            for r in recipesPerUser[user]:
                sim_score = Jaccard(usersPerRecipe[recipe],usersPerRecipe[r])
                if sim_score > i:
                    condition_met = True
                    break
                else: continue
            # if satisfy either thresholds
            if condition_met or recipe in top_popular:
                predicts.append(1)
            else:
                predicts.append(0)
                
    return predicts

# %%
temp_result = cooking_model(revised_valid_tuples,0.63,0.642)

# %%
import numpy as np

# %%
def accuracy_score(p,titles):
    return sum(np.array(p) == np.array(titles))/len(p)

# %%
actual = [1]*100000 + [0]*100000

# %% [markdown]
# In fact this is the best accuracy score I can get from HW3 cooking prediction

# %%
# accuracy score of the model with popularity check and similarity check, where the popularity threshold is
# 0.642, and the jaccard similarity threshold is 0.63
accuracy_score(temp_result,actual)
# Out:
# 0.713105

# %%
TP_ = np.logical_and(temp_result,actual)
TN_ = np.logical_and(np.logical_not(temp_result),np.logical_not(actual))
FP_ = np.logical_and(temp_result,np.logical_not(actual))
FN_ = np.logical_and(np.logical_not(temp_result),actual)

# %%
TP = sum(TP_)
FN = sum(FN_)
FP = sum(FP_)
TN = sum(TN_)

# %%
# True positive rate
TPR = TP /(TP + FN)

# %%
# False positive rate
FPR = FP /(FP + TN)

# %%
TPR
# Out:
# 0.63939

# %%
FPR
# Out:
# 0.21318

# %% [markdown]
# Now I am gonna try implementing logistic regression, the X features that I am thinking are popularity score of the recipe, and the maximum Jaccard similarity score of the recipe to the recipes that the user has cooked. The pop score is defined by the percentile of the recipe amoung all of the recipes, i.e 100 would be the most popular recipes amoung all.

# %%
mostPopular[:10]
# Out:
# [(619, '74912490'),
#  (586, '29147042'),
#  (511, '05898774'),
#  (489, '37919560'),
#  (468, '98124873'),
#  (458, '67292161'),
#  (424, '48134500'),
#  (422, '63528663'),
#  (422, '63512895'),
#  (389, '36834291')]

# %%
len(mostPopular)
# Out:
# 151462

# %%
# assign the percentile score to each recipe
mostPop_percentile = defaultdict()
cnt = 0
for r in mostPopular:
    percentile = 100 - cnt/151462
    cnt += r[0]
    mostPop_percentile[r[1]] = percentile

# %%
def Jaccard(s1,s2):
    inter = s1.intersection(s2)
    union = s1.union(s2)
    if len(union) == 0:
        return 0
    else:
        return len(inter) / len(union)

# %%
# define the function find_jaccard to find the maximum jaccard similarity score between the recipe and the users' cooked recipe
def find_jaccard(r,u):
    temp = []
    for x in recipesPerUser[u]:
        if r == x:
            continue
        jacc_score = Jaccard(usersPerRecipe[r],usersPerRecipe[x])
        temp.append(jacc_score)
    # means that the user hasn't cooked anything before
    if len(temp) == 0:
        return 0
    else:
        return max(temp)

# %%
# in the form of (user_id, recipe_id)
revised_valid_tuples[0]
# Out:
# ('90764166', '01768679')

# %%
# now we define a function that transforms the X features
def feature(d):
    feat = []
    for data in d:
        temp_feat = [1]
        temp_feat.append(mostPop_percentile[data[1]])
        temp_feat.append(find_jaccard(data[1],data[0]))
        feat.append(temp_feat)
    return feat

# %%
# now we start transforming our features
X_cooking_valid = feature(revised_valid_tuples)

# %%
# the y here is basically our actual result, which is 100000 1's followed by 100000 0's
y_cooking_valid = actual

# %%
from sklearn import linear_model

# %%
# now we fit the X features and y into a logistic model
mod_cooking = linear_model.LogisticRegression(C=1.0, class_weight = 'balanced')
mod_cooking.fit(X_cooking_valid, y_cooking_valid)

predictions_cooking = mod_cooking.predict(X_cooking_valid)

# %%
accuracy_score(predictions_cooking,actual)
# Out:
# 0.713215

# %%
# adjust the C value to a larger value
mod_cooking = linear_model.LogisticRegression(C=40, class_weight = 'balanced')
mod_cooking.fit(X_cooking_valid, y_cooking_valid)

predictions_cooking = mod_cooking.predict(X_cooking_valid)

# %%
accuracy_score(predictions_cooking,actual)
# Out:
# 0.713255

# %%
sum(np.array(temp_result) == predictions_cooking)
# Out:
# 197034

# %%
len(predictions_cooking)
# Out:
# 200000

# %% [markdown]
# temp_result is our predictions from solely the popularity check and jaccard similarity threshold check,
# and that shows our predictions from the logistic regression model are mostly the same as our 'threshold check' model,
# the accuracy score only improves by around 0.02 percent, from 0.713105 to 0.713255.

# %% [markdown]
# And that shows we should probably include more features in our model.

# %% [markdown]
# I am going to include the average rating of the recipe in the X features. Basically that means we are trying to include the
# parameter that shows whether a high rating recipe tends to be cooked more or not.

# %%
recipe_Ratings = defaultdict(list)
for u,r,_ in dataset:
    recipe_Ratings[r].append(int(_['rating']))

# %%
# calculate the average rating of the recipe
recipe_avg_Ratings = defaultdict(int)
for r in recipe_Ratings.keys():
    recipe_avg_Ratings[r] = sum(recipe_Ratings[r])/len(recipe_Ratings[r])

# %%
# define a function that finds the average of the recipe's rating, if the recipe hasn't been rated before then return 0.
def find_avg_rating(r):
    return recipe_avg_Ratings[r]

# %%
# now we define a function that transforms the X features, including the average rating of the recipe
def feature_revised(d):
    feat = []
    for data in d:
        temp_feat = [1]
        if data[1] not in mostPop_percentile:
            temp_feat.append(0)
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            feat.append(temp_feat)
        else:
            temp_feat.append(mostPop_percentile[data[1]])
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            feat.append(temp_feat)
    return feat

# %%
X_cooking_revised = feature_revised(revised_valid_tuples)

# %%
y_cooking_valid = actual

# %%
# adjust the C value to a larger value
mod_cooking_revised = linear_model.LogisticRegression(C=1, class_weight = 'balanced')
mod_cooking_revised.fit(X_cooking_revised, y_cooking_valid)

predictions_cooking_revised = mod_cooking_revised.predict(X_cooking_revised)

# %%
# returns the accuracy score of the model that includes the feature indicating average rating of the recipe.
accuracy_score(predictions_cooking_revised,actual)
# Out:
# 0.71358

# %% [markdown]
# We can see that our accuracy score increases from 0.713255 to 0.71358, and that's approximately by 0.046 percent.

# %% [markdown]
# I am gonna try this model on kaggle

# %%
revised_valid_tuples[0]
# Out:
# ('90764166', '01768679')

# %%
temp_d = ('19934813','86257276')

# %%
temp_feature = feature_revised([temp_d])

# %%
temp_feature
# Out:
# [[1, 97.84327422059658, 0.3333333333333333, 5.0]]

# %%
temp_predict = mod_cooking_revised.predict(temp_feature)

# %%
temp_predict[0]
# Out:
# 1

# %%
temp_d = ('96078190','35608339')
temp_feature = feature_revised([temp_d])

# %%
None in temp_feature[0]
# Out:
# True

# %%
import random

# %%
# open the stub_Made.txt file to see the test_data and write my predictions to predictions_Made.txt file
predictions = open("predictions_Made.txt", 'w')
try:
    for l in open("stub_Made.txt"):
        if l.startswith("user_id"):
            #header
            predictions.write(l)
            continue
        u,i = l.strip().split('-')


        # here we apply the model that we just built and fitted
        temp_d = (u,i)
        temp_feature = feature_revised([temp_d])
        # if there is no feature at all for the recipe and user pair we simply predict 0.
        if None in temp_feature[0]:
                predictions.write(u + '-' + i + ",0\n")
        else:
            temp_predict = mod_cooking_revised.predict(temp_feature)
            if temp_predict[0] == 1:
                predictions.write(u + '-' + i + ",1\n")
            else:
                predictions.write(u + '-' + i + ",0\n")
            
except:
    print(u,i)
        
predictions.close()

# %% [markdown]
# The accuracy score on kaggle got improved by like 0.001, and I am thinking about including more features from the trainRecipes dataset.
# Because basically, even though including more features might not help us identify the recipes that we will not cook, it definitely
# helps with improving the accuracy of predicting what we would cook. So it's very likely that we increase our TPR by combining more features.

# %%
def readGz(path):
    for l in gzip.open(path, 'rt',encoding='utf-8'):
        yield eval(l)

# %%
dataset_recipes = []
for d in readGz("trainRecipes.json.gz"):
     dataset_recipes.append(d)

# %%
dataset_recipes[0]
# Out:
# {'name': 'sexy fried eggs for sunday brunch',
#  'minutes': 10,
#  'contributor_id': '14298494',
#  'submitted': '2004-05-21',
#  'steps': 'heat a ridged griddle pan\tlightly brush the tomato slices and bread with some olive oil\tcook the tomato slices first , for at least 5 minutes\twhen they are almost ready , toast the bread in the same pan until well bar-marked\tin the meantime , pour a little olive oil into a small frying pan and crack in the egg\tallow it to set for a minute or so and add the garlic and chilli\tcook for a couple of minutes , spooning the hot oil over the egg until cooked to your liking\tplace the griddled bread on a plate and quickly spoon the tomatoes on top\tthrow the chives into the egg pan and splash in the balsamic vinegar\tseason well , then slide the egg on to the tomatoes and drizzle the pan juices on top\tserve immediately , with a good cup of tea !',
#  'description': 'this is from silvana franco\'s book "family" which i love. i made these for brunch yesterday and we loved them so much that we had them again today!',
#  'ingredients': ['plum tomato',
#   'ciabatta',
#   'olive oil',
#   'egg',
#   'garlic clove',
#   'chili',
#   'chives',
#   'balsamic vinegar',
#   'salt and pepper'],
#  'recipe_id': '06432987'}

# %%
recipe_minutes = defaultdict(int)
recipe_description = defaultdict()
recipe_ingre = defaultdict(set)
recipe_name = defaultdict()

# %%
# loop through the recipe dataset to store the info into corresponding dict
for r in dataset_recipes:
    recipe_minutes[r['recipe_id']] = r['minutes']
    recipe_description[r['recipe_id']] = r['description']
    recipe_ingre[r['recipe_id']] = r['ingredients']
    recipe_name[r['recipe_id']] = r['name']

# %% [markdown]
# First I would like to see the pattern of average cooking minutes for the cooked recipe and for those not cooked recipe

# %%
cooked_minutes = []
not_cooked_minutes = []
for d in revised_valid_tuples[:100000]:
    cooked_minutes.append(recipe_minutes[d[1]])
for d in revised_valid_tuples[100000:]:
    not_cooked_minutes.append(recipe_minutes[d[1]])

# %%
sum(cooked_minutes)/len(cooked_minutes), sum(not_cooked_minutes)/len(not_cooked_minutes)
# Out:
# (62.20032, 58.81477)

# %% [markdown]
# See the pattern of length of description of cooked vs not cooked

# %%
cooked_description = []
not_cooked_description = []
for d in revised_valid_tuples[:100000]:
    cooked_description.append(len(recipe_description[d[1]]))
for d in revised_valid_tuples[100000:]:
    not_cooked_description.append(len(recipe_description[d[1]]))

# %%
sum(cooked_description)/len(cooked_description), sum(not_cooked_description)/len(not_cooked_description)
# Out:
# (217.54758, 194.91585)

# %% [markdown]
# See the pattern of number of ingredients of cooked vs not cooked

# %%
cooked_ingre = []
not_cooked_ingre = []
for d in revised_valid_tuples[:100000]:
    cooked_ingre.append(len(recipe_ingre[d[1]]))
for d in revised_valid_tuples[100000:]:
    not_cooked_ingre.append(len(recipe_ingre[d[1]]))

# %%
sum(cooked_ingre)/len(cooked_ingre), sum(not_cooked_ingre)/len(not_cooked_ingre)
# Out:
# (8.80692, 8.94691)

# %% [markdown]
# See the pattern of length of names of cooked vs not cooked

# %%
cooked_name = []
not_cooked_name = []
for d in revised_valid_tuples[:100000]:
    cooked_name.append(len(recipe_name[d[1]]))
for d in revised_valid_tuples[100000:]:
    not_cooked_name.append(len(recipe_name[d[1]]))

# %%
sum(cooked_name)/len(cooked_name), sum(not_cooked_name)/len(not_cooked_name)
# Out:
# (28.40796, 27.54331)

# %% [markdown]
# I know the pattern above might not help that much because the compatibility for each user and recipe might be different, and that
# difference would lead to the fact that each feature matters differently to them. So now I would implement those features into our model,
# and to avoid overfitting, I would try only implement cooking minutes and length of description at first.

# %%
# define a function that finds the cooking time in minutes of the recipe
def find_minutes(r):
    if r in recipe_minutes:
        return recipe_minutes[r]
    else:
        return 0

# %%
# define a function that finds the length of the description of the recipe
def find_des(r):
    if r in recipe_description:
        return len(recipe_description[r])
    else:
        return 0

# %%
# now we define a function that transforms the X features, including the cooking minutes and the length of description
def feature_revised_02(d):
    feat = []
    for data in d:
        temp_feat = [1]
        if data[1] not in mostPop_percentile:
            temp_feat.append(0)
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_minutes(data[1]))
            temp_feat.append(find_des(data[1]))
            feat.append(temp_feat)
        else:
            temp_feat.append(mostPop_percentile[data[1]])
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_minutes(data[1]))
            temp_feat.append(find_des(data[1]))
            feat.append(temp_feat)
    return feat

# %%
X_cooking_revised_02 = feature_revised_02(revised_valid_tuples)

# %%
X_cooking_revised_02[0]
# Out:
# [1, 98.96498131544546, 0.08333333333333333, 4.923076923076923, 55, 132]

# %%
y_cooking_valid = [1]*100000 +[0]*100000

# %%
mod_cooking_revised_02 = linear_model.LogisticRegression(C=0.1, class_weight = 'balanced')
mod_cooking_revised_02.fit(X_cooking_revised_02, y_cooking_valid)

predictions_cooking_revised_02 = mod_cooking_revised_02.predict(X_cooking_revised_02)
# Out:
# C:\Users\YH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_score(predictions_cooking_revised_02,y_cooking_valid)
# Out:
# 0.71582

# %% [markdown]
# This seems to be the highest accuracy score so far on the revised validation set, and I am going to try this model on kaggle

# %%
# open the stub_Made.txt file to see the test_data and write my predictions to predictions_Made.txt file
predictions = open("predictions_Made.txt", 'w')
try:
    for l in open("stub_Made.txt"):
        if l.startswith("user_id"):
            #header
            predictions.write(l)
            continue
        u,i = l.strip().split('-')


        # here we apply the model that we just built and fitted
        temp_d = (u,i)
        temp_feature = feature_revised_02([temp_d])
        # if there is no feature at all for the recipe and user pair we simply predict 0.
        if None in temp_feature[0]:
                predictions.write(u + '-' + i + ",0\n")
        else:
            temp_predict = mod_cooking_revised_02.predict(temp_feature)
            if temp_predict[0] == 1:
                predictions.write(u + '-' + i + ",1\n")
            else:
                predictions.write(u + '-' + i + ",0\n")
            
except:
    print(u,i)
        
predictions.close()

# %% [markdown]
# I got 0.70440 on the kaggle, which is the highest accuracy score I can get so far.

# %%
recipe_ingre['01768679']
# Out:
# ['bacon',
#  'celery',
#  'onion',
#  'salt',
#  'all-purpose flour',
#  'sugar',
#  'vinegar',
#  'fresh ground pepper',
#  'water',
#  'potatoes']

# %%
# define a function that finds the number of ingredients of a recipe 
def find_ingre(r):
    if r in recipe_ingre:
        return len(recipe_ingre[r])
    else:
        return 0

# %%
# now we define a function that transforms the X features, including the number of ingredients
def feature_revised_03(d):
    feat = []
    for data in d:
        temp_feat = [1]
        if data[1] not in mostPop_percentile:
            temp_feat.append(0)
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_minutes(data[1]))
            temp_feat.append(find_des(data[1]))
            temp_feat.append(find_ingre(data[1]))
            feat.append(temp_feat)
        else:
            temp_feat.append(mostPop_percentile[data[1]])
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_minutes(data[1]))
            temp_feat.append(find_des(data[1]))
            temp_feat.append(find_ingre(data[1]))
            feat.append(temp_feat)
    return feat

# %%
X_cooking_revised_03 = feature_revised_03(revised_valid_tuples)

# %%
y_cooking_valid = actual

# %%
mod_cooking_revised_03 = linear_model.LogisticRegression(C=1000, class_weight = 'balanced')
mod_cooking_revised_03.fit(X_cooking_revised_03, y_cooking_valid)

predictions_cooking_revised_03 = mod_cooking_revised_03.predict(X_cooking_revised_03)
# Out:
# C:\Users\YH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_score(predictions_cooking_revised_03,y_cooking_valid)
# Out:
# 0.71151

# %% [markdown]
# Now I try to focus on the ingredients elements. Basically I want to find the popularity percentile of all the ingredients in each recipe
# and apply that as a feature.

# %%
# first create a dict that stores the count of all ingredients
ingre_cnt = defaultdict(int)
for d in dataset_recipes:
    for i in d['ingredients']:
        ingre_cnt[i] += 1

# %%
# sort the ingredients based on popularity
mostPopular_ingre = [(y, x) for x,y in ingre_cnt.items()]
mostPopular_ingre.sort()
mostPopular_ingre.reverse()

# %%
# find the percentile for each ingredient
mostPop_ingre_percentile = defaultdict()
cnt = 0
for r in mostPopular_ingre:
    percentile = 100 - cnt/151462
    cnt += r[0]
    mostPop_ingre_percentile[r[1]] = percentile

# %%
# define a function that returns the maximum percentile for each ingredient of the recipe
def find_ingre_percentile(r):
    # if the recipe does not appear in our train recipe dataset we return 0
    if r not in recipe_ingre:
        return 0
    else:
        temp = recipe_ingre[r]
        cur = []
        for x in temp:
            cur.append(mostPop_ingre_percentile[x])
        return max(cur)

# %%
# now we define a function that transforms the X features, including the maximum percentile for each ingredient of the recipe;
# decide not to use the length of the ingredients as a feature, since that tends to give us low accuracy score.
def feature_revised_04(d):
    feat = []
    for data in d:
        temp_feat = [1]
        if data[1] not in mostPop_percentile:
            temp_feat.append(0)
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_minutes(data[1]))
            temp_feat.append(find_des(data[1]))
            temp_feat.append(find_ingre_percentile(data[1]))
            feat.append(temp_feat)
        else:
            temp_feat.append(mostPop_percentile[data[1]])
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_minutes(data[1]))
            temp_feat.append(find_des(data[1]))
            temp_feat.append(find_ingre_percentile(data[1]))
            feat.append(temp_feat)
    return feat

# %%
X_cooking_revised_04 = feature_revised_04(revised_valid_tuples)

# %%
y_cooking_valid = actual

# %%
mod_cooking_revised_04 = linear_model.LogisticRegression(C=1.2, class_weight = 'balanced')
mod_cooking_revised_04.fit(X_cooking_revised_04, y_cooking_valid)

predictions_cooking_revised_04 = mod_cooking_revised_04.predict(X_cooking_revised_04)

# %%
accuracy_score(predictions_cooking_revised_04,y_cooking_valid)
# Out:
# 0.71351

# %%
# open the stub_Made.txt file to see the test_data and write my predictions to predictions_Made.txt file
predictions = open("predictions_Made.txt", 'w')
try:
    for l in open("stub_Made.txt"):
        if l.startswith("user_id"):
            #header
            predictions.write(l)
            continue
        u,i = l.strip().split('-')


        # here we apply the model that we just built and fitted
        temp_d = (u,i)
        temp_feature = feature_revised_04([temp_d])
        # if there is no feature at all for the recipe and user pair we simply predict 0.
        if None in temp_feature[0]:
                predictions.write(u + '-' + i + ",0\n")
        else:
            temp_predict = mod_cooking_revised_04.predict(temp_feature)
            if temp_predict[0] == 1:
                predictions.write(u + '-' + i + ",1\n")
            else:
                predictions.write(u + '-' + i + ",0\n")
            
except:
    print(u,i)
        
predictions.close()

# %% [markdown]
# The accuracy score I get on kaggle is 0.70180, which is lower than the model_2 I got.

# %% [markdown]
# Try the model that includes the cosine similarity feature

# %%
ratingDict = {} # To retrieve a rating for a specific user/recipe pair

for u,r,_ in dataset:
    user,recipe = u,r
    ratingDict[(user,recipe)] = int(_['rating'])

# %%
import math

# %%
def Cosine(i1, i2):
    # Between two items
    inter = usersPerRecipe[i1].intersection(usersPerRecipe[i2])
    numer = 0
    denom1 = 0
    denom2 = 0
    for u in inter:
        numer += (ratingDict[(u,i1)])*(ratingDict[(u,i2)])
    for u in inter:
        denom1 += (ratingDict[(u,i1)])**2
        denom2 += (ratingDict[(u,i2)])**2
    denom = math.sqrt(denom1) * math.sqrt(denom2)
    if denom == 0: 
        return 0
    return numer / denom

# %%
# function that returns the maximum cosine similarity score between the target recipe and the recipes cooked by the user
def find_cos(r,u):
    temp = []
    for x in recipesPerUser[u]:
        temp.append(Cosine(r,x))
    if len(temp) == 0:
        return 0
    else:
        return max(temp)

# %%
# here we implement the model_02, the one that we got highest accuracy score previously, and include the cosine similarity attribute
def feature_revised_05(d):
    feat = []
    for data in d:
        temp_feat = [1]
        if data[1] not in mostPop_percentile:
            temp_feat.append(0)
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_minutes(data[1]))
            temp_feat.append(find_des(data[1]))
            temp_feat.append(find_cos(data[1],data[0]))
            feat.append(temp_feat)
        else:
            temp_feat.append(mostPop_percentile[data[1]])
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_minutes(data[1]))
            temp_feat.append(find_des(data[1]))
            temp_feat.append(find_cos(data[1],data[0]))
            feat.append(temp_feat)
    return feat

# %%
X_cooking_revised_05 = feature_revised_05(revised_valid_tuples)

# %%
y_cooking_valid = actual

# %%
mod_cooking_revised_05 = linear_model.LogisticRegression(C=100, class_weight = 'balanced')
mod_cooking_revised_05.fit(X_cooking_revised_05, y_cooking_valid)

predictions_cooking_revised_05 = mod_cooking_revised_05.predict(X_cooking_revised_05)
# Out:
# C:\Users\YH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_score(predictions_cooking_revised_05,y_cooking_valid)
# Out:
# 0.71817

# %%
# open the stub_Made.txt file to see the test_data and write my predictions to predictions_Made.txt file
predictions = open("predictions_Made.txt", 'w')
try:
    for l in open("stub_Made.txt"):
        if l.startswith("user_id"):
            #header
            predictions.write(l)
            continue
        u,i = l.strip().split('-')


        # here we apply the model that we just built and fitted
        temp_d = (u,i)
        temp_feature = feature_revised_05([temp_d])
        # if there is no feature at all for the recipe and user pair we simply predict 0.
        if None in temp_feature[0]:
                predictions.write(u + '-' + i + ",0\n")
        else:
            temp_predict = mod_cooking_revised_05.predict(temp_feature)
            if temp_predict[0] == 1:
                predictions.write(u + '-' + i + ",1\n")
            else:
                predictions.write(u + '-' + i + ",0\n")
            
except:
    print(u,i)
        
predictions.close()

# %% [markdown]
# kaggle score decreases to 0.70050, and I am so confused

# %%
# here we implement the model_02, the one that we got highest accuracy score previously, and include the cosine similarity attribute
def feature_revised_07(d):
    feat = []
    for data in d:
        temp_feat = [1]
        if data[1] not in mostPop_percentile:
            temp_feat.append(0)
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_des(data[1]))
            temp_feat.append(find_cos(data[1],data[0]))
            feat.append(temp_feat)
        else:
            temp_feat.append(mostPop_percentile[data[1]])
            temp_feat.append(find_jaccard(data[1],data[0]))
            temp_feat.append(find_avg_rating(data[1]))
            temp_feat.append(find_des(data[1]))
            temp_feat.append(find_cos(data[1],data[0]))
            feat.append(temp_feat)
    return feat

# %%
X_cooking_revised_07 = feature_revised_07(revised_valid_tuples)

# %%
y_cooking_valid = actual

# %% [markdown]
# Try using ridge classifier

# %%
mod_cooking_revised_07 = linear_model.RidgeClassifier(1)
mod_cooking_revised_07.fit(X_cooking_revised_07, y_cooking_valid)

predictions_cooking_revised_07 = mod_cooking_revised_07.predict(X_cooking_revised_07)

# %%
accuracy_score(predictions_cooking_revised_07,y_cooking_valid)
# Out:
# 0.71834

# %%
# open the stub_Made.txt file to see the test_data and write my predictions to predictions_Made.txt file
predictions = open("predictions_Made.txt", 'w')
try:
    for l in open("stub_Made.txt"):
        if l.startswith("user_id"):
            #header
            predictions.write(l)
            continue
        u,i = l.strip().split('-')


        # here we apply the model that we just built and fitted
        temp_d = (u,i)
        temp_feature = feature_revised_07([temp_d])
        # if there is no feature at all for the recipe and user pair we simply predict 0.
        if None in temp_feature[0]:
                predictions.write(u + '-' + i + ",0\n")
        else:
            temp_predict = mod_cooking_revised_07.predict(temp_feature)
            if temp_predict[0] == 1:
                predictions.write(u + '-' + i + ",1\n")
            else:
                predictions.write(u + '-' + i + ",0\n")
            
except:
    print(u,i)
        
predictions.close()

# %% [markdown]
# Decide to sample more data to fit the model more accurately

# %%
revised_valid_new = train[:400000]

# %%
revised_valid_new_copy = revised_valid_new.copy()

# %%
# randomly select from all recipes and check whether it's cooked by that user, then create a negative pair 
# and append to the revised valid set

for data in revised_valid_new_copy:
    cooked = True
    while cooked:
        random_entry = random.sample(recipeCount.keys(),1)
        if random_entry[0] not in recipesPerUser[data[0]]:
            if (data[0],random_entry[0]) not in revised_valid_new:
                revised_valid_new.append((data[0],random_entry[0]))
                cooked = False

# %%
# %store revised_valid_new
# Out:
# Stored 'revised_valid_new' (list)

# %%
# %store -r revised_valid_new

# %%
# now we have revised_valid_new to be our new validation set, the first 400000 entries are cooked, 
# and the last 400000 entries are uncooked
len(revised_valid_new)
# Out:
# 800000

# %%
revised_valid_new_tuples = []
for x in revised_valid_new[:400000]:
    temp = (x[0],x[1])
    revised_valid_new_tuples.append(temp)
for x in revised_valid_new[400000:]:
    revised_valid_new_tuples.append(x)

# %%
len(set(revised_valid_new_tuples))
# Out:
# 800000

# %%
X_cooking_revised_new_02 = feature_revised_02(revised_valid_new_tuples)

# %%
# %store X_cooking_revised_new_02
# Out:
# Stored 'X_cooking_revised_new_02' (list)

# %%
# %store -r X_cooking_revised_new_02

# %%
X_cooking_revised_new_02_smaller = X_cooking_revised_new_02[:150000] + X_cooking_revised_new_02[400000:550000]

# %%
len(X_cooking_revised_new_02_smaller)
# Out:
# 300000

# %%
X_test = X_cooking_revised_new_02[150000:400000] + X_cooking_revised_new_02[550000:]

# %%
len(X_test)
# Out:
# 500000

# %%
y_cooking_valid_new = [1]*400000 + [0]*400000

# %%
y_cooking_valid_new_smaller = [1]*150000 + [0]*150000

# %%
y_test = [1]*250000 + [0]*250000

# %%
mod_cooking_revised_new_02 = linear_model.LogisticRegression(C=1,class_weight='balanced')
mod_cooking_revised_new_02.fit(X_cooking_revised_new_02_smaller, y_cooking_valid_new_smaller)

predictions_cooking_revised_new_02 = mod_cooking_revised_new_02.predict(X_cooking_revised_new_02_smaller)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-266-8f25a0cec72d> in <module>
#       1 mod_cooking_revised_new_02 = linear_model.LogisticRegression(C=1,class_weight='balanced')
# ----> 2 mod_cooking_revised_new_02.fit(X_cooking_revised_new_02_smaller, y_cooking_valid_new_smaller)
#       3
#       4 predictions_cooking_revised_new_02 = mod_cooking_revised_new_02.predict(X_cooking_revised_new_02_smaller)
#
# NameError: name 'X_cooking_revised_new_02_smaller' is not defined

# %%
accuracy_score(predictions_cooking_revised_new_02, y_cooking_valid_new_smaller)
# Out:
# 0.8417933333333333

# %%
predictions_test = mod_cooking_revised_new_02.predict(X_test)

# %%
accuracy_score(predictions_test, y_test)
# Out:
# 0.842684

# %%
# open the stub_Made.txt file to see the test_data and write my predictions to predictions_Made.txt file
predictions = open("predictions_Made.txt", 'w')
try:
    for l in open("stub_Made.txt"):
        if l.startswith("user_id"):
            #header
            predictions.write(l)
            continue
        u,i = l.strip().split('-')


        # here we apply the model that we just built and fitted
        temp_d = (u,i)
        temp_feature = feature_revised_02([temp_d])
        temp_predict = mod_cooking_revised_new_02.predict(temp_feature)
        if temp_predict[0] == 1:
            predictions.write(u + '-' + i + ",1\n")
        else:
            predictions.write(u + '-' + i + ",0\n")
            
except:
    print(u,i)
        
predictions.close()

# %%
counter = 0
for l in open("predictions_Made.txt"):
    if l.startswith("user_id"):
        continue
    u,i = l.strip().split(',')
    counter += int(i)
counter
# Out:
# 6133

# %%
d = ('03425965', '44197323')

# %%
mod_cooking_revised_new_02.predict(feature_revised_02([d]))[0]
# Out:
# 1

# %%
recipe_avg_Ratings['35608339']
# Out:
# 0

# %%
find_avg_rating('35608339')
# Out:
# 0

# %%
X_cooking_revised_new_02[0]
# Out:
# [1, 98.58423234870793, 1, 4.75, 30, 212]

# %%
temp_X = X_cooking_revised_new_02[:200000] + X_cooking_revised_new_02[400000:600000]
temp_y = [1]*200000 + [0]*200000

# %%
temp_X = []
for x in X_cooking_revised_new_02[:300000] + X_cooking_revised_new_02[400000:700000]:
    temp_X.append(x)

# %%
temp_y = [1]*300000 + [0]*300000

# %%
mod_cooking_revised_new_02 = linear_model.RidgeClassifier(10000)
mod_cooking_revised_new_02.fit(temp_X, temp_y)

predictions_cooking_revised_new_02 = mod_cooking_revised_new_02.predict(temp_X)

# %%
accuracy_score(predictions_cooking_revised_new_02, temp_y)
# Out:
# 0.9190566666666666

# %%
d = ('96078190','35608339')

# %%
feature_revised_02([d])
# Out:
# [[1, 0, 0.0, None, 35, 114]]

# %%
recipe_minutes['35608339']
# Out:
# 35

# %%
recipe_description['35608339']
# Out:
# 'this recipe comes from shira kestenbaum, a regular on the israel-food discussion list. posted with her permission.'

# %%
recipe_Ratings['35608339']
# Out:
# []

# %%
temp = []
for l in open("predictions_Made.txt"):
    if l.startswith("user_id"):
        continue
    u,i = l.strip().split(',')
    temp.append((u,i))

# %%
temp1 = []
for x in temp:
    temp1.append(x[0].split('-'))

# %%
recipes = usersPerRecipe.keys()

# %%
temp2_appeared = []
for x in temp1:
    if x[1] in temp3:
        temp2_appeared.append(x)

# %%
len(temp2_appeared)
# Out:
# 20000

# %%
temp3 = set()
for x in dataset_recipes:
    temp3.add(x['recipe_id'])

# %%
len(temp3)
# Out:
# 199805

# %%
len(dataset_recipes)
# Out:
# 200000

# %%
# Out:
# 20000

# %%
test_recipes = []
for d in readGz("testRecipes.json.gz"):
    test_recipes.append(d)

# %%
test_recipes
# Out:
# [{'name': 'rhubarb pie ii',
#   'contributor_id': '75346189',
#   'submitted': '2000-03-13',
#   'steps': 'combine all ingredients except butter or margarine\tline a 9" pie plate with orange pastry\tfill with rhubarb mixture and dot with the butter or margarine\ttop with lattice crust\tbake at 400 degrees 40 to 50 minutes\tserve warm with vanilla ice cream',
#   'description': '',
#   'ingredients': ['rhubarb',
#    'flour',
#    'sugar',
#    'salt',
#    'orange rind',
#    'butter'],
#   'recipe_id': '79578623'},
#  {'name': 'ww 6 points mediterranean roast chicken',
#   'contributor_id': '91918778',
#   'submitted': '2007-09-11',
#   'steps': 'preheat oven to 400f\tspray roasting rack with nonstick spray\tspray nonstick baking sheet with nonstick spray\tcombine chopped thyme , oregano , oil , garlic , and salt in small bowl\tgently loosen skin from breast of chicken\tspread the herbs evenly under the skin\tplace lemon inside cavity\ttuck wings begind chicken and tie legs together\tplace chicken , breast side up , on rack\tplace potatoes and olives on baking sheet\troast chicken until thigh registers 180f , about 1 hr and 10 minute\tduring last 45 min , place potatoes and olives in oven\tstir occasionally , until potatoes are tender and browned\tlet chicken stand 10 minute\tdiscard lemon and skin , then carve\tgarnish with thyme sprigs',
#   'description': 'from ww simply delicious',
#   'ingredients': ['thyme',
#    'dried oregano',
#    'olive oil',
#    'garlic clove',
#    'salt',
#    'roasting chickens',
#    'lemon',
#    'red potatoes',
#    'kalamata olives',
#    'fresh thyme sprig'],
#   'recipe_id': '34742403'},
#  {'name': 'sweet salty grilled cheese sandwich',
#   'contributor_id': '80498782',
#   'submitted': '2009-03-24',
#   'steps': 'spread a thin coat of butter or mayonnaise on one side of each slice of bread\ton unbuttered side , layer cheese and dates\tcover with the second slice , buttered side out\tpreheat a frying pan on med-high heat\tplace sandwich in pan\tcook 2-3 minutes until golden and cheese has melted enough that you can flip it without everything slipping out\tflip over , flatten with spatula if desired\tcook another 2-3 minutes until golden',
#   'description': "this is my favourite way to eat this classic comfort food and express meal. i know everyone has their own way of making it, but i'm posting this recipe because most people probably haven't thought about adding dates. quantities will vary depending on the size of your bread and your personal taste. enjoy!",
#   'ingredients': ['bread', 'sharp cheddar cheese', 'dates', 'butter'],
#   'recipe_id': '27205316'},
#  {'name': 'taco pie in pie crust',
#   'contributor_id': '23850148',
#   'submitted': '2006-11-26',
#   'steps': 'brown meat > drain fat and season\tunroll crust , put into 9 or 10 inch pie plate\tbake crust for about 10 minutes until just starting to bubble\tspread beans on pie crust\tlayer half of meat , chilis and cheese\tlayer other half of meat , chilis and cheese\ttop with crumbled corn chips\tbake in 350 degree oven for about 25-30 minutes\tserve with guacamole , olives , tomatoes , lettuce , salsa and sour cream',
#   'description': 'yummy twist on tacos > no mess! this is the best taco pie recipe. everyone loves this one. great as leftovers or to make an extra and freeze it for later.',
#   'ingredients': ['refrigerated pie crust',
#    'ground beef',
#    'refried beans',
#    'diced green chilies',
#    'cheddar cheese',
#    'taco seasoning',
#    'doritos',
#    'guacamole',
#    'salsa',
#    'sour cream',
#    'black olives',
#    'tomatoes',
#    'lettuce'],
#   'recipe_id': '15313464'},
#  {'name': 'blueberry bran muffins',
#   'contributor_id': '53251961',
#   'submitted': '2009-02-16',
#   'steps': 'preheat oven to 375f and grease a 12 cup muffin pan\ttoss cereal with sugar , flour , baking soda and salt\tin a seperate bowl , whisk oil , egg and buttermilk\tadd buttermilk mixture to cereal mixture and stir just until blended\tstir in blueberries and spoon into prepared muffin tin\tbake for 20 to 25 minutes , until tester inserted in the centre of a muffin comes out clean',
#   'description': 'i made these muffins last week to go in the lunches - all 3 boys liked them and they used up some cereal that was just about past its prime! recipe is courtesy of anna olson, from her cookbook another cup of sugar.',
#   'ingredients': ['raisin bran cereal',
#    'sugar',
#    'all-purpose flour',
#    'baking soda',
#    'fine salt',
#    'canola oil',
#    'egg',
#    'buttermilk',
#    'blueberries'],
#   'recipe_id': '72546246'},
#  {'name': 'southern chicken parmegian',
#   'contributor_id': '47029529',
#   'submitted': '2007-10-31',
#   'steps': 'i am remembering this recipe straight from my head , so bare w / me !\tpreheat your oven to 350 degrees\tin two shallow dishes mix the cornmeal , dry italian mix & bread crumbs together\tin the other shallow dish , lightly beat both eggs\tin a frying pan , pour 1 / 2 cup of olive oil\tdip each piece of chicken into the egg mixture then continue to the cornmeal / breadcrumb / italian seasoning mixture and put in the frying pan\tafter you have repeated that step w / each piece of chicken , let each piece fry for about 2-3 min on each side , or until both sides are golden brown\tplace your golden brown chicken in a 13 x 9 baking dish & pop it in the over for 15 minutes\tafter 15 minutes is up , pour the entire jar of marinara on chicken and pop back in over for another 15 minutes\tafter 15 minutes , pour both mozzarella & parmesan cheese mixture over chicken and pop in over for another 15 minutes\tthe total baking time is 45 minutes and this dish goes great with fettuccine alfredo',
#   'description': "this is a delicious recipe and it's super easy and fun to make...it can be easy, but you must follow directions! i saw the recipe one day in paula deen's home cooking & i added a few of my personal touches and it's delicious!",
#   'ingredients': ['eggs',
#    'cornmeal',
#    'breadcrumbs',
#    'italian salad dressing mix',
#    'marinara sauce',
#    'mozzarella cheese',
#    'parmesan cheese',
#    'olive oil',
#    'boneless chicken breasts'],
#   'recipe_id': '47960528'},
#  {'name': 'chocolate intemperance',
#   'contributor_id': '87895866',
#   'submitted': '2008-03-18',
#   'steps': "in a medium saucepan , whisk together the cocoa , sugar , cornstarch , and salt\tslowly whisk in the water , then the flavor of your choice , if using , and the milk or cream\tbring to a boil over medium heat , whisking constantly\tremove from the heat and stir in the chocolate , whisking till chocolate melts\tpour into a bowl , and stir ooccasionally as it cools , to prevent a skin from forming\tpour into a jar or other storage container , and lay a piece of plastic wrap right on the surface of the chocolate , again to prevent a skin from forming\tstore in the refrigerator for up to a week\tto serve:\tserve as is in very small glasses\tit's thick and it's rich\tto make one frozen smoothie , place 1 / 3 cup of chocolate base in a blender\tadd about 1 cup ice cubes(and 1 oz\tof the spirit of your choice , if desired , and blend till smooth\talternately , blend with chunks of banana , or a scoop of ice cream\tfeeling intemperate ? add vodka and coffee liqueur to 1 / 3 to 1 / 2 cup chocolate base for the best sweet martini ever ! to rim glass with cinnamon sugar , mix\t1 teaspoons cinnamon with 2 tablespoons sparkling sugar and 1 tablespoons granulated sugar\twipe the edge of the glass with a wet cloth , then dip it into the sugar mixture",
#   'description': "this is a wonderful thick, rich chocolate drink that is delish as is, or as a base; blend it with ice and make it a smoothie! either way, it's fantastic! source: internet. note: you can use 1 tsp. cinnamon, for the vanilla, all are optional or 1 tablespoon espresso powder, for the vanilla, all are optional",
#   'ingredients': ['dutch-processed cocoa powder',
#    'sugar',
#    'cornstarch',
#    'salt',
#    'water',
#    'vanilla',
#    'milk',
#    'semisweet chocolate'],
#   'recipe_id': '17168696'},
#  {'name': 'apple brandy hot toddy',
#   'contributor_id': '50667903',
#   'submitted': '2009-02-18',
#   'steps': 'heat water to boiling\tpour brandy and honey liqueur or honey into a heatproof glass\tadd water and nutmeg and stir with a cinnamon stick or bar spoon\tfloat lemon wedge on top and serve',
#   'description': "got this in an email from www.chow.com - made it up because it turned cold here! used honey instead of the recommended honey liqueur (have to go out of state to snag some of that). it's delicious, bone warming & soothing! wonderful for a cold evening snugged in with someone you love... or a good book... or a great movie... or reruns of the wire...",
#   'ingredients': ['water',
#    'calvados',
#    'honey liqueur',
#    'nutmeg',
#    'cinnamon stick',
#    'lemon wedge'],
#   'recipe_id': '34908790'},
#  {'name': 'holiday ambrosia fruit fluff',
#   'contributor_id': '83301801',
#   'submitted': '2007-10-12',
#   'steps': 'in a small bowl toss the cranberries with sugar\tset aside for 30 minutes at room temperature\tin a large bowl combine the marshmallows with chopped apples , grape halves , pineapple and chopped pecans\tadd in the sugar-coated cranberries and toss to combine\tfold in the cool whip topping\tcover and chill until ready to use\tbefore serving sprinkle with coconut',
#   'description': 'whipped cream may be used in place of cool whip if desired but the cool whip tends to hold up better for this salad, and you may adjust the amount to taste --- not only is this delicious this colourful dessert makes a wonderful presentation to serve at your holiday table, it may be be made well in advance! :)',
#   'ingredients': ['fresh cranberries',
#    'sugar',
#    'mini marshmallows',
#    'red apples',
#    'seedless grapes',
#    'pineapple tidbits',
#    'pecans',
#    'frozen whipped topping',
#    'shredded coconut'],
#   'recipe_id': '56026880'},
#  {'name': 'roasted rosemary potatoes with garlic',
#   'contributor_id': '35839550',
#   'submitted': '2003-04-16',
#   'steps': 'preheat oven to 400\tplace the potatoes and garlic in a shallow baking dish large enough to hold them in a single layer\tdrizzle with the oil and toss well to evenly coat\tsprinkle with the rosemary , salt and freshly ground pepper\ttoss again\troast , uncovered , for 40-50 minutes , depending on size , turning halfway through cooking time , or until the potatoes are nicely browned and tender through the center\tserve hot\tserves 6',
#   'description': 'this italian favorite pairs up especially well with the recipes i posted for mediterranean roasted green beans with slivered amonds recipe #21300 and/or roasted asparagus recipe #21148. from the mediterranean vegan kitchen.',
#   'ingredients': ['red potatoes',
#    'garlic',
#    'extra virgin olive oil',
#    'dried rosemary',
#    'salt',
#    'fresh ground pepper'],
#   'recipe_id': '81190852'},
#  {'name': 'tomato beef',
#   'contributor_id': '45790819',
#   'submitted': '2000-03-16',
#   'steps': 'marinate beef slices for 30 minutes\theat wok with 2 t oil and garlic for 30 seconds , add beef , cook for 1 1 / 2 to 2 minutes , remove and drain oil\tset aside\theat wok , high , add tomato wedges and stir for 2 minutes , then add sauce mixture\tthicken if too watery\treturn beef and stir well and serve hot\tserve immediately',
#   'description': '',
#   'ingredients': ['flank steak',
#    'tomatoes',
#    'green onions',
#    'garlic',
#    'oil',
#    'soy sauce',
#    'wine',
#    'water',
#    'sesame oil',
#    'cornstarch',
#    'tomato ketchup',
#    'sugar',
#    'vinegar',
#    'salt and pepper'],
#   'recipe_id': '39457672'},
#  {'name': 'autumn salad with apples and candied walnuts',
#   'contributor_id': '22116917',
#   'submitted': '2008-12-18',
#   'steps': 'nuts: preheat oven tp 350 degrees\tcombine walnuts and butter in glass baking dish\tbake 15 minutes , stirring every 5 minutes\tcombine sugar and pepper and toss warm walnuts in mixture to coat\tlet cool and store in jar in fridge\tdressing: blend all ingredients , except oin in processor or blender\twith it running , slowly add oil\tsalad: assemble and toss with dressing right before serving\tto keep apples from turning brown , place slices in a zip lock with a little lemon juice and water and shake',
#   'description': "i got this recipe from and friend and it is my favorite salad. i like to use a lot more sugar than the recipe calls for - about 2-3 tablespoons, but i'll leave the recipe as written and you can sweeten to taste. i also like to use pecans in place of the walnuts.",
#   'ingredients': ['butter',
#    'walnuts',
#    'ground black pepper',
#    'sugar',
#    'garlic clove',
#    'dried oregano',
#    'fresh parsley',
#    'sweet onion',
#    'white wine vinegar',
#    'olive oil',
#    'salt and pepper',
#    'romaine lettuce',
#    'granny smith apple',
#    'gala apples',
#    'feta cheese'],
#   'recipe_id': '33662989'},
#  {'name': 'beach bum smoothie from tropical smoothie cafe',
#   'contributor_id': '89906947',
#   'submitted': '2008-12-14',
#   'steps': 'melt chocolate in microwave for about 1 to 1 1 / 2 minutes , just enough until the chocolate is soft\tadd all ingredients to blender , blend until smooth',
#   'description': 'my all time favorite smoothie from tropical smoothie cafe! strawberries,bananas, and white chocolate! yum!',
#   'ingredients': ['milk',
#    'frozen strawberries',
#    'banana',
#    'sugar',
#    'white chocolate square',
#    'ice'],
#   'recipe_id': '62801356'},
#  {'name': 'prawn fettuccine in white sauce',
#   'contributor_id': '58221496',
#   'submitted': '2006-10-05',
#   'steps': 'put fettucine on to boil in water with some oil and salt\tshould not take long to cook\tin a large frying pan , saute onion garlic and spring onions until soft\tadd prawns and toss through until cooked\tadd white wine and stock and mix through\tadd cream slowly , mixing through until you get desired quantity but not too much otherwise it will taste of all cream\tadd cornflour to thicken the cream sauce\tcheck fettucine is ready and drain if ready\tadd more crushed garlic to cream sauce if you think it needs more\tadd salt and pepper to taste\tin a large dish add hald fettucine and half the sauce and mix through\tthen add the other half of the fettucine and the other half of the sauce and mix through\tserve with grated or shaved parmesan cheese on top and warm oven baked dinner rolls',
#   'description': 'a very tasty creamy pasta dish, good for cooking when you have company. be careful though, you may have too much fettucine per sauce quantity so if this is the case, do not use all the fettucine as it will take away the richness of the sauce. another alternative is to use rice as the base rather than the pasta.',
#   'ingredients': ['large shrimp',
#    'spring onion',
#    'garlic cloves',
#    'thickened cream',
#    'white wine',
#    'chicken stock',
#    'cornflour',
#    'cold water',
#    'chili flakes',
#    'salt & pepper',
#    'olive oil',
#    'fresh fettuccine',
#    'fresh parmesan cheese',
#    'dinner rolls'],
#   'recipe_id': '92491996'},
#  {'name': 'green beans with mushrooms and crisp onion crumbs',
#   'contributor_id': '74833012',
#   'submitted': '2009-12-11',
#   'steps': 'for the crumb topping:\tmelt butter over medium-low heat\tadd panko bread crumbs , onions and salt\tsaute about 6 minutes or until crumbs are slightly toasted\tfor the green beans and mushrooms:\tsteam green beans and mushrooms in pressure cooker according to your directions\tplace green beans and mushrooms in serving dish\ttop with crumb topping',
#   'description': "this comes from the weight watchers site. i'm posting it mostly to add it to my shopping list. however, it was very tasty. my directions are for how i will cook it the next time (reduce the butter, steam the green beans). using smart balance omega butter blend, each serving is 1 point. cooking time includes bringing the pressure cooker to pressure.",
#   'ingredients': ['butter',
#    'panko breadcrumbs',
#    'dried onion flakes',
#    'salt',
#    'green beans',
#    'button mushroom'],
#   'recipe_id': '70506903'},
#  {'name': 'mai tais',
#   'contributor_id': '17410761',
#   'submitted': '2004-06-25',
#   'steps': 'combine all liquid ingredients in a large pitcher\tcut lime into 8 wedges\tpour mixture into 8 tall ice-filled glasses\tadd one lime wedge to each glass\tsip and enjoy',
#   'description': 'a taste of the tropics that serves a group. perfect for summer get-togethers.',
#   'ingredients': ['dark rum',
#    'light rum',
#    'coffee liqueur',
#    'orange liqueur',
#    'pineapple juice',
#    'orange juice',
#    'lime'],
#   'recipe_id': '94715209'},
#  {'name': 'black eyed pea salsa relish',
#   'contributor_id': '58294292',
#   'submitted': '2009-01-07',
#   'steps': "1\tin a large bowl , combine oil , vinegar , mustard , sugar , celery seed , salt , and pepper\tmix until well combined\t2\tadd celery , green onions , bell pepper , cucumber , jalapeno , and cilantro\tmix into dressing until well covered\t3\tadd the corn and peas\tmix well\t4\tcover and refrigerate for at least an hour , but it tastes better if you let it sit a little longer\ti will use this as a topping for grilled chicken , or you can eat it like a dip\ti've even added twisty pasta to it and made it into a pasta salad\tenjoy !",
#   'description': 'call it a relish....call it a dip....call it a salsa...or call it a side dish...i call it delicious! a friend of mine got this recipe from "the pioneer woman cooks" website, but i\'ve changed a few things and added some of my own stuff. even if you don\'t like black-eyed peas, you\'ll like this! even my little girl gobbles it up when i make it.',
#   'ingredients': ['olive oil',
#    'white vinegar',
#    'brown mustard',
#    'sugar',
#    'celery seed',
#    'salt',
#    'ground pepper',
#    'celery',
#    'green onions',
#    'red bell pepper',
#    'cucumber',
#    'jalapeno',
#    'cilantro',
#    'black-eyed peas',
#    'white corn'],
#   'recipe_id': '22953865'},
#  {'name': 'cavatappi with arugula pesto and cherry tomatoes',
#   'contributor_id': '16455750',
#   'submitted': '2006-06-01',
#   'steps': 'pesto: combine first 7 ingredients in a food processor\tprocess until finely minced\twith processor on , slowly pour 1 / 3 cup water and oil through food chute\tprocess until well blended\tcook pasta according to package directions , omitting salt and fat\tdrain\tcombine pesto , pasta , and tomatoes in a large bowl\ttoss well\tsprinkle pine nuts over pasta\tserve immediately',
#   'description': 'from cooking light, june 2006.',
#   'ingredients': ['arugula',
#    'fresh parmesan cheese',
#    'pine nuts',
#    'lemon juice',
#    'salt',
#    'fresh ground black pepper',
#    'garlic clove',
#    'water',
#    'olive oil',
#    'cavatappi pasta',
#    'yellow cherry tomatoes'],
#   'recipe_id': '72028659'},
#  {'name': 'raisin eggnog bread pudding',
#   'contributor_id': '04676371',
#   'submitted': '2008-01-04',
#   'steps': 'butter or spray a 13x9 inch baking dish\tput bread pieces in a bowl , pour eggnog over the bread and allow to soak for about 1 hour , or until all the liquid is absorbed\tposition oven rack in the middle position\tpreheat oven to 350\tin a bowl , whisk the eggs , yolks , sugar , brandy , and rum until thick and smooth\tstir in the bread mixture and pour into prepared pan\tsprinkle nutmeg over the top\tplace the dish in a large shallow pan , such as a roasting pan , lined with a dish towel\tplace the pan on the oven rack , and pour enough hot water into the larger pan to come halfway up the sides of the pudding dish\tbake for 1 hour or just until the center is set when gently shaken\ttransfer to a baking rack to cool slightly\tserve with freshly whipped cream',
#   'description': 'festive holiday dessert.',
#   'ingredients': ['raisin bread',
#    'eggnog',
#    'eggs',
#    'egg yolks',
#    'sugar',
#    'brandy',
#    'dark rum',
#    'nutmeg',
#    'whipped cream'],
#   'recipe_id': '08160453'},
#  {'name': 'chinese duck salad',
#   'contributor_id': '44776294',
#   'submitted': '2002-01-19',
#   'steps': 'mix the dressing with a whisk\tplace ingredients in a salad bowl\ttoss with dressing\tserve over iceberg lettuce',
#   'description': "i have not made this salad but posted it by request. it is from jeff smith's",
#   'ingredients': ['boneless duck meat',
#    'bean sprouts',
#    'coriander',
#    'iceberg lettuce',
#    'light soy sauce',
#    'sesame oil',
#    'sugar',
#    'sesame seeds',
#    'pepper'],
#   'recipe_id': '42192557'},
#  {'name': 'garden bean and potato salad with balsamic vinaigrette',
#   'contributor_id': '32934453',
#   'submitted': '2003-02-05',
#   'steps': 'vinaigrette: combine all the ingredients in a jar\tcover tightly and shake vigorously\tyield: 1 cup\tarrange potatoes in steamer basket over boiling water\tcover and steam 20 minutes or until tender\tplace in large serving bowl\tarrange beans in steamer basket over boiling water\tcover and steam 10 minutes or until crisp tender\thalve the potatoes and add the beans , onion , and basil\tadd the vinaigrette to potato mixture and toss gently\tserve at once or cover and chill',
#   'description': 'use fresh vegetables for this and you are in for a real treat--this in a wonderful dish.',
#   'ingredients': ['small red potatoes',
#    'fresh green beans',
#    'purple onion',
#    'fresh basil',
#    'extra virgin olive oil',
#    'balsamic vinegar',
#    'dijon mustard',
#    'fresh lemon juice',
#    'salt',
#    'pepper',
#    'worcestershire sauce',
#    'garlic clove'],
#   'recipe_id': '53952610'},
#  {'name': 'honey lemonade with raspberry cubes',
#   'contributor_id': '95482435',
#   'submitted': '2005-08-15',
#   'steps': 'combine lemon juice and honey in a large pitcher\tstir until honey is dissolved\tstir in water\tplace 1 to 2 pieces of raspberry fruits in each compartment of two ice trays\tfill each compartment with honey lemonade anf freeze until firm\tchill remaining lemonade\tto serve , divide frozen fruit cubes between tall glasses and fill with remainiing honey lemonade',
#   'description': 'from sue bee honey, this is a beautiful lemonade to behold! cooking time is actually freezing time. enjoy!',
#   'ingredients': ['honey', 'lemon juice', 'water', 'raspberries'],
#   'recipe_id': '22633187'},
#  {'name': 'how to get kids to eat their veggies spaghetti sauce',
#   'contributor_id': '95482435',
#   'submitted': '2003-01-24',
#   'steps': 'in a large saucepan , saute vegetables and garlic for 5-7 minutes in olive oil\tadd spaghetti sauce , tomato sauce , corn , sugar , basil , oregano and 1 cup water\tif using meat , brown and add now\tbring to a boil , then turn down heat to low , cover and simmer for 1 to 1 1 / 2 hours\tstir occasionally , adding water if it gets too thick\tadd salt and pepper to taste\twhen nearly done , cook pasta as directed on package , drain , and serve with sauce\tyou may add any other vegs\tyou like\tserve with garlic bread and a nice salad\tenjoy !',
#   'description': "this is how i used to get my kids to eat their vegetables when all they wanted was meat in their sauce! it cooks down to a wonderful consistency and they all love it, even now when they're all grown up!",
#   'ingredients': ['spaghetti sauce',
#    'tomato sauce',
#    'zucchini',
#    'sweet corn',
#    'red pepper',
#    'carrot',
#    'onion',
#    'celery',
#    'olive oil',
#    'garlic',
#    'brown sugar',
#    'basil',
#    'oregano',
#    'ground beef',
#    'salt and pepper',
#    'spaghetti noodles',
#    'water'],
#   'recipe_id': '05750691'},
#  {'name': 'coquilles st jacques',
#   'contributor_id': '72301996',
#   'submitted': '2003-05-29',
#   'steps': 'if using large scallops , cut into 3 or 4 pieces\tin med\tsaucepan , cook and stir onion in butter until tender\tadd scallops , lemon juice , salt , marjoram leaves , paprika , and wine\tsimmer uncovered 10 minutes\tadd mushrooms\tsimmer 2 minutes longer\tdrain liquid from scallop mixture\tset aside\tmelt 1 / 3 cup butter in medium saucepan over low heat\tstir in flour\tcook over low heat until mixture is smooth and bubbly\tremove from heat\tstir in reserved liquid and cream\theat to boiling , stirring constantly\tboil and stir for 1 minute , then add parsley\treserve 1 / 2 cup sauce\tadd the rest to the scallop and mushroom mixture\theat through , stirring often\tspoon scallop mixture into six individual baking dishes\tspread each with 1 tbs\treserved sauce\tmelt 1 tbs\tbutter in small skillet\tadd bread crumbs , stirring until brown\tplace baking dishes on baking sheet\tset oven to"broil"\tbroil dishes 6 inches from heat 5 to 8 minutes or until bubbly and brown\tsprinkle crumbs over the tops and serve',
#   'description': 'a la parisienne - popular version of a traditional baked scallop recipe',
#   'ingredients': ['sea scallops',
#    'onions',
#    'butter',
#    'lemon juice',
#    'salt',
#    'marjoram leaves',
#    'paprika',
#    'dry white wine',
#    'mushrooms',
#    'flour',
#    'whipping cream',
#    'parsley',
#    'breadcrumbs'],
#   'recipe_id': '01505200'},
#  {'name': 'addictive cheeseburger pizza',
#   'contributor_id': '34892064',
#   'submitted': '2004-02-11',
#   'steps': 'brown the burger , sausage , green pepper , onion , and garlic until the meat is fully cooked\twhile this is cooking , spread / pat / roll your crust unto a greased jelly roll pan , pushing the dough up the sides to make an edge\tprebake the crust in a 400 oven for 7-10 minutes or until it just begins to color\ttop the hot crust with the desired amount of pasta sauce\tadd the meat mixture , spreading evenly\ttop with the sliced velveeta cheese , leaving about 1 / 2 inch between slices\tadd the mozzarella cheese in an even layer\tbake at 400 for about 20 minutes , or until the top layer of cheese begins to brown\tallow to sit for 5 minutes before cutting into 12 squares',
#   'description': 'the comment i hear from everyone the first time they eat this is,',
#   'ingredients': ['lean hamburger',
#    'italian sausage',
#    'green pepper',
#    'onion',
#    'garlic',
#    'marinara sauce',
#    'mozzarella cheese',
#    'velveeta cheese',
#    'pizza dough'],
#   'recipe_id': '32412714'},
#  {'name': 'skulls monsters',
#   'contributor_id': '53000255',
#   'submitted': '2006-06-15',
#   'steps': "skulls: shape 4 krispy treats into skulls\tplace on wire rack over wax paper\tdivide frosting between 2 microwave-safe bowls\tmicrowave 1 bowl stirring every 10 seconds until frosting is pourable\tspoon over skulls to cover\tpour rest into small ziptop bag\treserve\tput m&m's in place for eyes and noses\tmonsters: put remaining treats on rack\tusing food colors , tint frosting in other bowl to match tic tacs\tmicrowave until pourable\tspoon over treats\tadd sprinkles for hair and tic tacs for eyelids and bolts\trefrigerate to set\twait a while\tcut a\tmelt chocolate chips , stirring until smooth\tspoon into another ziptop bag and cut off\twith red gel , pipe scars on monster\trefrigerate until serving",
#   'description': 'these are a wonderful halloween treat and yummy rice crispy treat.',
#   'ingredients': ['rice krispies treats',
#    'white frosting',
#    'green food coloring',
#    'yellow food coloring',
#    "miniature m&m's chocolate candies",
#    'chocolate sprinkles',
#    'tic tac mint',
#    'semi-sweet chocolate chips',
#    'red decorating gel'],
#   'recipe_id': '70581626'},
#  {'name': 'creole spinach salad',
#   'contributor_id': '19431643',
#   'submitted': '2005-06-29',
#   'steps': 'to prepare , macerate the minced garlic in the extra virgin olive oil for at least 15 minutes , preferably while preparing the remaining ingredients\tset aside\tin a skillet , preferably non-stick , render the fat from the bacon over medium heat\tthis will take about 5-10 minutes\twhen the bits of bacon are cooked , remove them and set aside , leaving the hot fat in the pan\tadd the celery , onion , and green pepper and saute until the onions become translucent\tretaining as much of the extra virgin olive oil as possible , add the minced garlic and saute until the garlic turns light brown on the edges\tadd the andouille sausage and saute until browned\tadd the cilantro , balsamic vinegar , and molasses and stir\twile the liquids reduce , prepare a salad bowl or serving platter with a bed of the spinach greens\tlayer the lump crab meat , slivered almonds , and feta cheese over the spinach\tseason the salad with salt and pepper to taste\tadd the remaining extra virgin olive oil to the hot skilled and spoon it over the salad to serve',
#   'description': 'again, this is one of those recipes that i came up with while fooling around with pretty standard ingredients. it could be spicier (maybe with the addition of some cayenne or hot sauce) or, perhaps, smokier with the addition of a dark roux, but i like it in its current incarnation.',
#   'ingredients': ['bacon',
#    'celery',
#    'vidalia onions',
#    'green bell peppers',
#    'garlic cloves',
#    'extra virgin olive oil',
#    'andouille sausages',
#    'balsamic vinegar',
#    'molasses',
#    'cilantro',
#    'salt and black pepper',
#    'spinach',
#    'lump crabmeat',
#    'slivered almonds',
#    'feta cheese'],
#   'recipe_id': '48274570'},
#  {'name': 'pudding cream frosting',
#   'contributor_id': '01457343',
#   'submitted': '2003-02-18',
#   'steps': 'in bowl , beat cream to stiff peaks\tset aside\tin another bowl , beat pudding mix with milk on low speed for 1 minute\tlet set 1 minute\tfold in whipped cream\tchill until ready to use',
#   'description': 'a simple cream frosting that can be adapted to any flavour of instant pudding. i like using vanilla, lemon, and chocolate flavours. this frosting is especially good on angel food cake, because it is not too sweet.',
#   'ingredients': ['whipping cream', 'instant pudding mix', 'milk'],
#   'recipe_id': '94846770'},
#  {'name': 'moroccan olive omelette bayd de zaitun',
#   'contributor_id': '53464336',
#   'submitted': '2013-07-17',
#   'steps': 'in a medium sized bowl , lightly beat the eggs\tstir in the olives , parsley , caraway and cumin\tseason with salt and pepper\theat the oil in a very hot non-stick frying pan\tpour the mixture into the pan , move the pan to distribute evenly and leave for 7 seconds without stirring\ttilt the pan and move the cooked egg to the center with a spatula , allowing the uncooked egg to replace the cooked egg\twhen there is the hint of uncooked egg left , fold the omelette in half and transfer to a warm platter , sprinkle with paprika and tarragon\tcut into 2 or 3 pieces and serve immediately',
#   'description': 'an unsual omelette from morocco, filled with black olives.',
#   'ingredients': ['eggs',
#    'black olives',
#    'fresh parsley',
#    'caraway seed',
#    'ground cumin',
#    'salt & freshly ground black pepper',
#    'olive oil',
#    'sweet paprika',
#    'fresh tarragon'],
#   'recipe_id': '59083941'},
#  {'name': 'debbie s taco dip',
#   'contributor_id': '89461748',
#   'submitted': '2003-01-14',
#   'steps': 'spread refried beans on a pizza pan\tsprinkle with 1 / 3 of taco seasoning\tspread mashed avacados over bean layer\tsprinkle with 1 / 3 of taco seasoning\tspread sour cream over avacado layer\tsprinkle with 1 / 3 of taco seasoning\tsprinkle cheeses evenly over sour cream layer\ttop with black olive slices and diced tomatoes if you choose\tserve with tortilla chips',
#   'description': "stand back and watch it disappear! people eat this stuff up so fast...and they go wild for the avacados. if you're not into fat-free or light, feel free to use the full fat options.",
#   'ingredients': ['refried beans',
#    'taco seasoning mix',
#    'avocados',
#    'light sour cream',
#    'monterey jack cheese',
#    'cheddar cheese',
#    'black olives',
#    'diced tomato'],
#   'recipe_id': '86877533'},
#  {'name': 'chicken with mustard cream',
#   'contributor_id': '20028793',
#   'submitted': '2008-05-18',
#   'steps': 'saute chicken in oil until well browned on all sides\tadd 1 teaspoon of alino--rz does not recognize this spice combination\tadd salt and pepper to your taste\talso add the onions , mushrooms and bell pepper , saute 5 minutes\tcover and cook 10 minutes\tadd garlic , mustard and sour cream\theat through but do not boil\tserve over rice or noodles , sprinkled with cheese',
#   'description': 'hola! this chilean recipe is from http://recipes.wuzzle.org/. here is the alino spice recipe recipe#304144. you are suppose to add in one teaspoon of alino seasoning in step 2 and b/c rz did not recognize it i could not put it inside the directions. notice that the parmesan cheese is put over the rice or noodles.',
#   'ingredients': ['chicken breast',
#    'olive oil',
#    'salt and pepper',
#    'onion',
#    'mushrooms',
#    'red bell pepper',
#    'garlic cloves',
#    'dijon mustard',
#    'sour cream',
#    'parmesan cheese'],
#   'recipe_id': '72701762'},
#  {'name': 'make a snake sandwich',
#   'contributor_id': '91277833',
#   'submitted': '2005-10-25',
#   'steps': 'prehat oven to 375f\tline a cookie sheet with foil , grease and set aside\tdust a flat surface with flour and spread out the crescent dough being careful not to separate\tpinch the seams together so it is 1 piece of dough\twith a rolling pin , roll out into a large rectangle , being careful to not get too thin\tbrush dough with mustard to 1 inch of the edge\tlayer meats down the middle of the rectangle , leaving a 1 inch border\tlayer cheese over the meats\tfold lengthwise , 1 side of the dough over the filling to the center of the meat / cheese mixture\tfold the other side over and press the dough to seal in the filling\tlightly beat 1 egg yolk\tbrush the egg yolk over the top of the dough to "glue" the pieces together\tfold the dough lengthwise in half again , pinching the seam to seal\ttaper one end of the snake to make a tail and form the other end into a head\tbeat the remaining 2 egg yolks and separate into 3 small bowls\tadd food coloring to each bowl to make colors of your choice\tusing a pastry brush , paint stripes , dots or the design of your choice onto the snake with the egg yolk mixture\ttransfer the snake to the foil-lined baking sheet\tform the snake into an "s" or other shape\tinsert 2 cloves into the head for nostrils\tcut the red pepper into a tongue shape and insert into the head\tbake for 15-20 minutes or until golden brown and cooked through\tinsert toothpick into the olives and insert into the snakes head to create the eyes\tserve your snake !',
#   'description': 'i saw paula deen make this on foodtv for a halloween show and it looked like so much fun. ds and i did have a blast making it. ds thought it was so great to have a snake for dinner. more fun with food! :) change the meats & cheeses to whatever tickles your fancy. i mostly "eyeballed" when making this so not sure if i used the exact amounts specified. i didn\'t need a whole bell pepper so got a couple of strips from the grocery salad bar. now what to do with the rest of the jar of olives!?!',
#   'ingredients': ['crescent rolls',
#    'flour',
#    'spicy mustard',
#    'salami',
#    'bologna',
#    'monterey jack cheese',
#    'food coloring',
#    'egg yolks',
#    'cloves',
#    'toothpick',
#    'pimento stuffed olives',
#    'red pepper'],
#   'recipe_id': '88677556'},
#  {'name': 'pierogies ole',
#   'contributor_id': '48542995',
#   'submitted': '2003-12-30',
#   'steps': 'thaw pierogies in boiling water 5 minutes , drain and keep warm\tin the meantime , combine chili and salsa in a skillet\tcook over medium high heat until hot and bubbly , about 4 minutes\treduce heat to medium , add corn and cook 6 minutes\tpour chili mix over pierogies and top with cheese',
#   'description': 'frozen pierogies are the perfect base for quick fix main dishes.',
#   'ingredients': ['pierogi',
#    'chili with beans',
#    'salsa',
#    'frozen corn',
#    'sharp cheddar cheese'],
#   'recipe_id': '04278512'},
#  {'name': 'colorful bean stew casserole',
#   'contributor_id': '07092896',
#   'submitted': '2002-11-15',
#   'steps': 'spray non stick skillet with vegetable spray , heat pan , add onion , pepper , garlic and saute 3 minutes or until tender\tadd tomatoes and water and bring to a boil\tadd macaroni and spices\treduce heat\tcover and simmer until macaroni is cooked\tadd drained beans and cheese\tcook 5 minutes to heat through , serve',
#   'description': '',
#   'ingredients': ['vegetable oil cooking spray',
#    'onion',
#    'green pepper',
#    'garlic',
#    'tomatoes',
#    'elbow macaroni',
#    'water',
#    'oregano',
#    'basil',
#    'pepper',
#    'garbanzo beans',
#    'kidney beans',
#    'parmesan cheese'],
#   'recipe_id': '15595292'},
#  {'name': 'pumpkin orange cookies',
#   'contributor_id': '27573372',
#   'submitted': '2002-10-22',
#   'steps': 'mix flour , baking soda and salt in med bowl\tin lg bowl , beat butter and sugars until creamy\tadd egg , pumpkin , orange juice and peel , beat until combined\tstir in nuts\tdrop dough by rounded tbs onto lightly sprayed baking skeets\tbake at 375 for 12 minutes , until light brown\tcool on wire racks\tglaze: mix all ingredients in med bowl until smooth\tspread each cookie with glaze',
#   'description': 'you really need to have these for thanksgiving treats!!!',
#   'ingredients': ['flour',
#    'baking soda',
#    'salt',
#    'butter',
#    'sugar',
#    'brown sugar',
#    'egg',
#    'canned pumpkin',
#    'orange juice',
#    'orange zest',
#    'pecans',
#    'powdered sugar'],
#   'recipe_id': '41147372'},
#  {'name': 'weight watchers mini chocolate chip cookies',
#   'contributor_id': '23782958',
#   'submitted': '2010-01-26',
#   'steps': 'preheat oven to 375 and line a cookie sheet with parchment paper\tin medium bowl , cream butter , oil and brown sugar\tadd vanilla , salt and egg white and mix thoroughly\tin separate bowl , stir together flour , baking soda and chocolate chips\tuse wooden spoon to add flour mixture to cream mixture\tdrop rounded 1 / 2tsp measurers of dough onto cookie sheet\tbake 4 - 6 minutes or until done to your liking',
#   'description': "i really wanted chocolate chip cookies but didn't want to sacrifice my points count for the day. this is a nice recipe that i took from the weight watchers website. be careful however, these cookies are so good and tasty that you will forget the 2 cookie rule. baking time was suggested at 4 - 6 minutes, however, mine took slightly longer.",
#   'ingredients': ['butter',
#    'canola oil',
#    'dark brown sugar',
#    'vanilla',
#    'salt',
#    'egg white',
#    'flour',
#    'baking soda',
#    'chocolate chips'],
#   'recipe_id': '25584340'},
#  {'name': 'pear clafouti',
#   'contributor_id': '38613703',
#   'submitted': '2006-04-10',
#   'steps': 'preheat the oven to 375 degrees f\tbutter a 10" round baking dish and sprinkle the bottom and sides with 1 tablespoon of the granulated sugar\tbeat the eggs and the 1 / 3 cup of granulated sugar on medium-high speed until light and fluffy , about 3 minutes\ton low speed , mix in the flour , cream , vanilla extract , lemon zest , salt , and pear brandy\tset aside for 10 minutes\tmeanwhile , peel , quarter , core , and slice the pears\tarrange the slices in a single layer , slightly fanned out , in the baking dish\tpour the batter over the pears and bake until the top is golden brown and the custard is firm , 35 to 40 minutes\tserve warm or at room temperature , sprinkled with confectioners\' sugar , and creme fraiche',
#   'description': "clafouti is a country french baked pudding, versatile enough to serve for breakfast, brunch, tea, or dinner, and suited to a wide variety of fruits. this is an ina garten (barefoot contessa) recipe that i'm putting here for safekeeping.",
#   'ingredients': ['unsalted butter',
#    'granulated sugar',
#    'extra-large eggs',
#    'all-purpose flour',
#    'heavy cream',
#    'vanilla extract',
#    'lemon zest',
#    'salt',
#    'pear brandy',
#    'bartlett pears',
#    "confectioners' sugar",
#    'creme fraiche'],
#   'recipe_id': '69328916'},
#  {'name': 'italiantomato bread salad',
#   'contributor_id': '46094863',
#   'submitted': '2002-02-07',
#   'steps': 'mix together the bread , tomatoes , and bell pepper in large bowl\twhisk together remaining ingredients\tpour over bread mixture and toss to coat\tcover and refrigerate at least 1 hour before serving\ttoss before serving',
#   'description': 'garlic and italian spices combine to create an easy salad that is perfect for picnics and barbeques (wonderful with grilled chicken). also, a great way to use up stale bread, or an over-abundance of garden tomatoes.',
#   'ingredients': ['italian bread',
#    'tomatoes',
#    'green bell pepper',
#    'garlic',
#    'dried basil',
#    'fresh parsley',
#    'olive oil',
#    'red wine vinegar',
#    'salt',
#    'black pepper'],
#   'recipe_id': '24774520'},
#  {'name': 'old fashioned molasses cookies',
#   'contributor_id': '14537615',
#   'submitted': '2005-06-07',
#   'steps': 'cream margarine and sugar , add eggs and molasses\tfinally add dry ingredients\troll in balls size of fifty cent piece\troll in sugar--do not flatten !\tbake on greased cookie sheet and bake at 350 for 10-12 minutes',
#   'description': "these are basically a soft ginger snap. i made them for my 8 year olds class and they were fighting over the extras. i also made them for a very sweet older friend who said she hadn't tasted these since her mother made them when she was little, they make a ton and stay fresh for quite awhile. this works perfectly for christmas or large amounts of company!",
#   'ingredients': ['margarine',
#    'sugar',
#    'eggs',
#    'molasses',
#    'flour',
#    'cinnamon',
#    'ginger',
#    'salt',
#    'baking soda'],
#   'recipe_id': '00750003'},
#  {'name': 'warm pepper jack cheese dip',
#   'contributor_id': '91198927',
#   'submitted': '2003-03-12',
#   'steps': 'combine all ingredients in a sauce pan or crockpot\theat over low heat for 45 min\tserve warm\tfor added spicyness , mince up some jalapenos and add to it',
#   'description': 'this is a good spicy dip i found on ivillage.',
#   'ingredients': ['monterey jack pepper cheese',
#    'onions',
#    'chili powder',
#    'hot sauce',
#    'garlic',
#    'beer'],
#   'recipe_id': '30444506'},
#  {'name': 'oooey gooey incredibly yummy banana cinnamon toast',
#   'contributor_id': '60936089',
#   'submitted': '2004-05-24',
#   'steps': 'first , you got to slice the muffins into round slices and toast them lightly\tremove onto a plate melt butter in a pan\tadd banana slices and saute till they brown a little and are soft\tstir in maple syrup , powdered cinnamon and the almonds\tmix lightly\tpour this mixture over the muffin slices\tremove onto a serving plate\tserve hot\tenjoy with full joy !',
#   'description': "try this guys and you will never stop eating it!! its the famous indian chef sanjeev kapoor's recipe from the young times magazine. enjoy:-)!",
#   'ingredients': ['bananas',
#    'ground cinnamon',
#    'muffins',
#    'almonds',
#    'unsalted butter',
#    'maple syrup'],
#   'recipe_id': '02621700'},
#  {'name': 'cornmeal fish sticks kid friendly',
#   'contributor_id': '33661791',
#   'submitted': '2010-06-09',
#   'steps': 'preheat oven to 250 degrees fahrenheit\tline a rimmed baking sheet with foil\tfit another with a wire rack\tin a large bowl , whisk together egg whites , 2 teaspoons salt , and 1 / 4 teaspoon pepper\tadd fish , and toss to coat\tin another large bowl , combine cornmeal , parmesan and flour\tseason with salt and pepper\tworking in batches , lift fish from egg-white mixture , and dredge in cornmeal mixture , patting to adhere\ttransfer to foil-lined sheet\tin a large skillet , heat oil over medium-high\tworking in batches , cook fish until golden brown and opaque throughout , 4 to 6 minutes , turning once\ttransfer to wire rack , and keep warm in oven while remaining fish cooks',
#   'description': "this is a favorite for all the kids in my family. i'm always asked to make this whenever my nieces and nephews come over. i serve it with both ketchup and tartar sauce to please all of them.",
#   'ingredients': ['egg whites',
#    'salt',
#    'pepper',
#    'tilapia fillet',
#    'yellow cornmeal',
#    'parmesan cheese',
#    'all-purpose flour',
#    'vegetable oil'],
#   'recipe_id': '90023531'},
#  {'name': 'beef and onion soup',
#   'contributor_id': '04676371',
#   'submitted': '2005-01-09',
#   'steps': 'in a big soup pot over medium-high heat , let the oil get warm\tadd in beef cubes\tstir / saut for 5 minutes or until meat is browned on all sides\ttransfer beef cubes to a plate\treduce heat to medium-low\tadd in butter and onions\tsaut / toss for about 6-7 minutes or until onions are slightly limp\tadd in beef stock , mustard , wine , salt , and pepper\tstir to combine\treturn beef cubes to pot\tbring to a boil , decrease heat to medium-low , cover and simmer for 30 minutes\tadd in parsley\tstir to combine\tadjust seasoning to taste\tladle soup into individual bowls\tsprinkle cheese over the top',
#   'description': 'nice when the weather is cool and crisp. i serve with toasted bruschetta.',
#   'ingredients': ['vegetable oil',
#    'round steak',
#    'butter',
#    'yellow onions',
#    'beef stock',
#    'dijon mustard',
#    'dry red wine',
#    'salt',
#    'fresh ground pepper',
#    'mushrooms',
#    'parsley',
#    'swiss cheese'],
#   'recipe_id': '95214510'},
#  {'name': 'venison soup stock',
#   'contributor_id': '33661791',
#   'submitted': '2010-05-14',
#   'steps': 'cut meat from bones\tmelt bacon fat in a heavy fry pan and brown meat on all sides\tplace browned meat and bones in large pot and cover with water\tadd remaining ingredients\tcover , bring to a boil on top of stove , then reduce heat and simmer 3 to 4 hours\tstrain , cool and remove the fat that has collected on surface\tstrain again if necessary\tpour in airtight containers , store in refrigerator for up to 3 days\tcan be frozen',
#   'description': 'this is a perfect way to use up those shank bones that are usually thrown out.',
#   'ingredients': ['venison',
#    'bacon fat',
#    'water',
#    'celery',
#    'carrot',
#    'onion',
#    'garlic cloves',
#    'thyme',
#    'marjoram',
#    'peppercorns',
#    'salt',
#    'parsley',
#    'whole cloves',
#    'bay leaves'],
#   'recipe_id': '10533043'},
#  {'name': 'german sweet sour eggs aka suess sauer eier',
#   'contributor_id': '50900766',
#   'submitted': '2004-09-02',
#   'steps': 'heat the oil in a skillet and have ready a cup or two of hot water\twhisk in the flour and cook until brown , stirring constantly--be careful not to burn the flour\tadd a small amount of hot water to the pan , whisking well , to create a sauce-like consistency , adding and whisking as needed\twhisk together the vinegar and the sugar , then add as much or as little to the sauce as you like\tcook eggs however you like them and serve with the sauce and some potatoes , if desired',
#   'description': 'posted by request. i am sharing this at the request of a member. this may be an acquired taste for some. translated from a recipe found on a german website.',
#   'ingredients': ['canola oil',
#    'all-purpose flour',
#    'hot water',
#    'salt',
#    'apple cider vinegar',
#    'granulated sugar',
#    'eggs',
#    'potatoes'],
#   'recipe_id': '37504356'},
#  {'name': 'oatmeal breakfast cake',
#   'contributor_id': '61030819',
#   'submitted': '2007-02-06',
#   'steps': 'preheat oven to 350\tcoat a 12 cup bundt pan with cooking spray\tcombine flour , oats , crumbs , sugars , baking powder , baking soda , cinnamon and salt\tin separate bowl , whisk together oil , buttermilk and eggs\tadd buttermilk mixture to dry ingredients and whisk until combined\tpour batter into prepared pan\tbake 40 minutes or until wooden pick inserted in the center comes out clean\tcool on a wire rack for 5 minutes\tremove from pan\tcool completely on wire rack',
#   'description': "i clipped this from the newspaper, gave it a try and it's delicious! very moist and flavorful, it could be served any time! after making it the original way first, i then tried it adding chopped walnuts and raisins and it was really good too! you could even drizzle it with a confectioners icing to dress it up. people are so creative, you could probably add just about anything to call it your own! :) freezes well too!",
#   'ingredients': ['all-purpose flour',
#    'old-fashioned oatmeal',
#    'graham cracker crumbs',
#    'brown sugar',
#    'granulated sugar',
#    'baking powder',
#    'baking soda',
#    'ground cinnamon',
#    'salt',
#    'vegetable oil',
#    'buttermilk',
#    'eggs'],
#   'recipe_id': '03824863'},
#  {'name': 'deluxe double chocolate cookies',
#   'contributor_id': '35524650',
#   'submitted': '2006-12-05',
# ...
#   'ingredients': ['olive oil',
#    'garlic',
#    'onion',
#    'salt',
#    'pepper',
#    'dried oregano',
#    'cinnamon',
#    'cumin',
#    'chili powder',
#    'tomatoes',
#    'kidney bean',
#    'black olives',
#    'barbecue sauce',
#    'red hot sauce',
#    'beer'],
#   'recipe_id': '51526004'},
#  {'name': 'garlic haricots verts almondine',
#   'contributor_id': '71528653',
#   'submitted': '2009-11-16',
#   'steps': 'place the oil and margarine in a skillet over medium-low heat until melted\tadd the haricots verts , stir , and cover for 3 minutes\tadd the sliced garlic , stir , and saute for 3 more minutes\tadd the remaining ingredients , stir , and saute for the final 3 minutes',
#   'description': 'this is a traditional thanksgiving recipe in our house. it is a healthier alternative to green bean casserole. you can use regular green beans, but they will need to steam for an extra 2-3 minutes.',
#   'ingredients': ['olive oil',
#    'margarine',
#    'french haricots vert',
#    'garlic cloves',
#    'almonds',
#    'sea salt',
#    'fresh ground black pepper'],
#   'recipe_id': '55228783'},
#  {'name': 'danny s favorite fettuccini alfredo',
#   'contributor_id': '35839550',
#   'submitted': '2002-10-07',
#   'steps': 'cook fettuccine in a 6- to 8-quart pot of boiling salted water until al dente\treserve 1 / 4 cup cooking water , then drain pasta in a colander\tmelt 3 / 4 stick butter in a 2- to 3-quart flameproof gratin dish over low heat\tadd cooked pasta and toss to coat , lifting strands\tadd cheese , reserved cooking water , cream , remaining 3 tablespoons butter , salt , and pepper and toss to combine well\tsprinkle with additional cheese and serve immediately\twhen salting water for cooking , use 1 tablespoon salt for every 4 quarts of water',
#   'description': 'this one is for you danny! your favorite dinner with tossed green salad and garlic butter italian bread!',
#   'ingredients': ['fettuccine',
#    'unsalted butter',
#    'parmigiano-reggiano cheese',
#    'heavy cream',
#    'salt',
#    'black pepper'],
#   'recipe_id': '14758787'},
#  {'name': 'ku u pua cocktail',
#   'contributor_id': '54496210',
#   'submitted': '2011-05-16',
#   'steps': 'rim a martini glass with the sugar\tfilla shaker with ice\tadd the fresh fruit and muddle\tadd the vodka , juices and coconut syrup\tshake vigorously\tstrain into the glass\tgarnish with the pineapple cube rolled in more sugar',
#   'description': 'a drink from the island menu of rachael ray.',
#   'ingredients': ['turbinado sugar',
#    'ice',
#    'fresh pineapple',
#    'oranges',
#    'vodka',
#    'passion fruit juice',
#    'guava juice',
#    'coconut syrup'],
#   'recipe_id': '78453989'},
#  {'name': 'rasgulla an indian dessert',
#   'contributor_id': '60936089',
#   'submitted': '2006-03-10',
#   'steps': 'in a bowl , knead together flour , cardamom powder and cheese until you get a smooth pliable dough\tdivide into equal parts\tshape into balls\tin a pot boil together the sugar and water to prepare a thin syrup\tdrop the prepared rasgullas into the boiling syrup\tlet it remain this way for 10 minutes\tevery 2 minutes , sprinkle water on the boiling syrup\tremove from heat and allow to cool\tflavour with rose water and store refrigerated - this must be served chilled\tenjoy !',
#   'description': 'this was submitted by jayakrishnan to young times in 2004. my dad loves these :) enjoy!',
#   'ingredients': ['cottage cheese',
#    'sugar',
#    'water',
#    'plain flour',
#    'cardamom powder',
#    'rose water'],
#   'recipe_id': '59956015'},
#  {'name': 'cocoa cherry spritz cookies',
#   'contributor_id': '45364111',
#   'submitted': '2009-10-31',
#   'steps': 'preheat oven to 375f\tbeat butter until light and fluffy\tadd sugar and continue beating until blended\tbeat in egg yolks\tbeat in vanilla extract\tbeat in cherry extract\tbeat in cocoa\tadd flour and mix well\tusing cookie press , press cookies out onto an ungreased baking sheet\tbake about 8 minutes , or until tops are dry but not browned',
#   'description': "if you don't have a cookie press, you can shape these with your hands.",
#   'ingredients': ['butter',
#    'sugar',
#    'egg yolks',
#    'vanilla extract',
#    'cherry extract',
#    'unsweetened cocoa',
#    'all-purpose flour'],
#   'recipe_id': '84491289'},
#  {'name': 'almond chicken kabobs',
#   'contributor_id': '45601931',
#   'submitted': '2007-08-25',
#   'steps': 'in small bowl , combine steak sauce , mustard , honey , oil , lemon juice and garlic\tset aside\tcut each chicken breast half into 8 cubes\tin medium nonmetal bowl , combine chicken cubes and 1 / 2 cup steak sauce mixture\tcover\tchill 1 hour , turning occasionally\tsoak 16 wooden skewers in water for at least 30 minutes\tthread 2 chicken cubes onto each skewer\tgrill kabobs over medium heat for 6 to 8 minutes or until done , turning and brushing with remaining sauce\tremove from grill\tquickly roll kabobs in almonds\tserve immediately',
#   'description': 'simple and easy appetizers from a-1 great grilling.',
#   'ingredients': ['a.1. original sauce',
#    'dijon mustard',
#    'honey',
#    'vegetable oil',
#    'lemon juice',
#    'garlic clove',
#    'boneless chicken breast halves',
#    'slivered almonds'],
#   'recipe_id': '51255965'},
#  {'name': 'make your own instant oatmeal oamc',
#   'contributor_id': '69803109',
#   'submitted': '2007-08-06',
#   'steps': 'assembly directions:\tmix various batches of several kinds of oatmeal\tfreezing directions:\tstore sealed mixture in freezer or pantry\tserving directions:\tto make one serving , scoop 1 / 2c of the mixture in a bowl\tadd 1c water and microwave for 2-3 minutes\tstir and let stand for another minute',
#   'description': 'great for fast breakfasts',
#   'ingredients': ['oatmeal',
#    'cinnamon',
#    'brown sugar',
#    'dried fruit',
#    'chocolate chips',
#    'walnuts'],
#   'recipe_id': '05056760'},
#  {'name': 'easy yummy cobbler',
#   'contributor_id': '10659782',
#   'submitted': '2004-07-01',
#   'steps': 'preheat oven to 350 degrees\tspread the pie filling in the bottom of a 9" x 13" pan\tcombine eggs , sugar and flour\tmixture will be crumbly\tspread the mixture evenly over pie filling\tpour the melted butter on top of crumble mixture\tsprinkle with cinnamon to taste\tbake for 30-40 minutes\ttopping should be golded brown',
#   'description': 'this recipe has been used by my mom, sister and myself for years. no one would believe how easy it is. top with vanilla ice cream or whipped cream for a yummy desert! apple and cherry are our favorites.',
#   'ingredients': ['pie filling',
#    'eggs',
#    'flour',
#    'sugar',
#    'butter',
#    'cinnamon'],
#   'recipe_id': '05330012'},
#  {'name': 'reiko s won tons',
#   'contributor_id': '96736067',
#   'submitted': '2009-07-23',
#   'steps': 'mix the first 6 ingredients in bowl\tthen use a heaping teaspoon of mixture and place in the middle of a won ton wrap\tfold at opposite ends to the middle and place a drop of water to stick in place\tit will be in the shape of a square\tyou can then flatten it a bit\tcontinue until all the mixture is gone\theat oil in a frying pan and fry for 2 minutes on each side\tdrain on paper towels\tput some soy sauce in a small bowl and dip won ton in it\tserve with hot steamed rice or fried rice',
#   'description': 'my mother was full blooded japanese and she came up with this recipe. it is very delicious!! we never really measured the ingredients but i will try and do the best that i can. it is a tedious job but well worth it! i am dedicating this recipe in memory of her. god bless you mom...i miss you terribly.',
#   'ingredients': ['lean ground beef',
#    'onion',
#    'egg',
#    'parsley flakes',
#    'kikkoman soy sauce',
#    'garlic cloves',
#    'wonton wrappers',
#    'rice',
#    'canola oil',
#    'water'],
#   'recipe_id': '01032688'},
#  {'name': 'baileys mocha frapp',
#   'contributor_id': '10698079',
#   'submitted': '2008-05-15',
#   'steps': 'place the ice cubes , baileys , instant coffee and milk in the jug of a blender and blend until almost smooth\tswirl the chocolate topping around the rim of 2 serving glasses\ttop with the baileys mixture to serve',
#   'description': 'mmmm baileys',
#   'ingredients': ['ice cubes',
#    'irish cream',
#    'instant coffee',
#    'milk',
#    'chocolate fudge topping'],
#   'recipe_id': '39333258'},
#  {'name': 'sweet spicy stir fry',
#   'contributor_id': '34625961',
#   'submitted': '2007-11-16',
#   'steps': 'prepare noodles according to pkt directions and set aside\theat oil in a wok over a high heat , stir-fry the meat , ginger & chilli for 2 mins or until browned\tset aside\tadd the carrots & capsicum , stir-fry for 2 minutes stir in the snow peas , red currant sauce , half the spring onions , water & vegemite\tbring to the boil stirring\treturn the meat to the pan with the noodles , tossing well to coat the noodles in the sauce\tsimmer until warmed through and add the cashews & coriander\tserve scattered with remaining spring onions',
#   'description': 'this goes well with practically any meat & has the aussie special ingredient vegemite. a really quick meal to throw together but super tasty.',
#   'ingredients': ['udon noodles',
#    'peanut oil',
#    'meat',
#    'ginger',
#    'dry crushed red pepper',
#    'carrots',
#    'red capsicum',
#    'snow peas',
#    'cranberry sauce',
#    'spring onions',
#    'water',
#    'vegemite',
#    'cashews',
#    'fresh coriander leaves'],
#   'recipe_id': '61116697'},
#  {'name': 'sunny s chocolate brownies',
#   'contributor_id': '14151159',
#   'submitted': '2008-12-31',
#   'steps': 'preheat oven to 350 deg f\tplace all the ingredients into a large bowl\toptional: add in 1 c chopped nuts\tmix at medium speed for 3 minutes\tspread into a 9x13" pan\tplace into the oven for 30 to 40 minutes\twhile baking , share the batter bowl with the kids\tbrownies will come out of the pan easier when they have cooled\ti can\'t usually wait that long though !\tcut into 32 small squares',
#   'description': 'from my cabin to yours... the right combination of cakeyness and gooeyness! so easy to make, my 9 year old whips these up for school bake sales.',
#   'ingredients': ['flour', 'sugar', 'cocoa', 'salt', 'eggs', 'oil', 'vanilla'],
#   'recipe_id': '20179502'},
#  {'name': 'deer camp food',
#   'contributor_id': '25408341',
#   'submitted': '2008-02-07',
#   'steps': 'in fry pan heat butter and add onions and garlic\tcook until lightly browned\tadd potatoes and cook until fork tender\tadd mushrooms and polish sausage\tmix well and cook until potatoes are crispy and everything is golden brown\tsprinkle cheese , cover and simmer 5 minutes or until cheese is melted',
#   'description': "my husband is a deer hunter. he recently took my daughter and they made this deer camp food. something i make all the time but she wouldn't eat it until dad called it this. very versatile recipe. can use any kind of meat, veggies, etc. i use a lot of leftover meats and veggies when making this.",
#   'ingredients': ['garlic cloves',
#    'butter',
#    'onions',
#    'potatoes',
#    'polish sausage',
#    'sliced mushrooms',
#    'cheddar cheese'],
#   'recipe_id': '67231802'},
#  {'name': 'mom s chinese chicken wings',
#   'contributor_id': '84575717',
#   'submitted': '2007-10-04',
#   'steps': 'rinse wings and pat dry\tmix all ingredients together and marinate overnight , turning a couple of times\tbake at 350f for 40-50 minutes\tturn them over halfway through cooking time\tbaste a couple of times as well',
#   'description': "this is my mother-in-law's recipe. i am always asking her to make it when we visit. i have made these for buffet get-togethers and serve them from a crock pot to keep them warm. i usually double the recipe. overnight marinating time is not included in prep time.",
#   'ingredients': ['chicken wings',
#    'soy sauce',
#    'oil',
#    'ground ginger',
#    'dry mustard',
#    'pepper',
#    'garlic powder',
#    'crushed pineapple',
#    'brown sugar'],
#   'recipe_id': '64581359'},
#  {'name': 'county fair chicken',
#   'contributor_id': '14672864',
#   'submitted': '2004-04-12',
#   'steps': 'combine parmesan cheese , flour , paprika , salt , and pepper\tmix egg and milk\tdip chicken in egg mixture , then coat with cheese mixture\tplace in 11 3 / 4 x 7 1 / 2 inch baking dish\tpour butter over chicken\tbake at 350 degrees for 1 hour',
#   'description': 'a very yummy baked chicken. even family that does not like chicken like this. since i married just one of those guys that hate chicken, was glad to find this as a young bride, 30+ years ago.',
#   'ingredients': ['parmesan cheese',
#    'flour',
#    'paprika',
#    'salt',
#    'pepper',
#    'chicken pieces',
#    'egg',
#    'milk',
#    'butter'],
#   'recipe_id': '32314144'},
#  {'name': 'amish corn pudding',
#   'contributor_id': '81818793',
#   'submitted': '2010-09-25',
#   'steps': 'preheat oven to 350\tbutter a 1 1 / 2 quart souffle or round baking dish and place in the oven\tmeanwhile , in a large bowl , with an electric mixer on high , beat the eggs , flour , sugar , and pepper until smooth\tstir in the milk , creamed corn , and corn kernels and pour into the hot dish\tdot with the butter and sprinkle with the paprika\tbake , uncovered , for 40 minutes or until set\tlet stand for 10 minutes , then sprinkle with the chopped parsley',
#   'description': "i've never had corn pudding before this, and i am sold. this is heavenly and simple to make. recipe courtesy of down home cooking.",
#   'ingredients': ['eggs',
#    'all-purpose flour',
#    'sugar',
#    'black pepper',
#    'low-fat milk',
#    'cream-style corn',
#    'corn kernel',
#    'unsalted butter',
#    'paprika',
#    'parsley'],
#   'recipe_id': '45822118'},
#  {'name': 'cream cheese filled chocolate chip cookie squares',
#   'contributor_id': '70734598',
#   'submitted': '2006-09-13',
#   'steps': 'slice 1 package of chocolate chip cookie dough and line the bottom of a cookie sheet with a lip\tlightly press down\tmix together the cream cheese , eggs , sugar and vanilla\tpour over the top of the cookie mix\tslice the other roll of cookies and place on top of cream cheese mixture\tbake at 350 degrees for 30 minutes\tlet cool a bit and then refrigerate\tcut into squares',
#   'description': "found this on the 'net. sounded sooo yummy, i just had to save it for later. will be trying this one soon!!!!!!",
#   'ingredients': ['refrigerated chocolate chip cookie dough',
#    'cream cheese',
#    'eggs',
#    'sugar',
#    'vanilla'],
#   'recipe_id': '84496528'},
#  {'name': 'pitta face mask',
#   'contributor_id': '66254702',
#   'submitted': '2008-01-09',
#   'steps': 'mix in a small bowl and apply to face',
#   'description': 'i saw this on the "ravensymonepresents" website. this is for if your skin is very sensitive,has both oily and dry areas,has low tolerance to hot food, and flares up with acne/rosacea/rashes.',
#   'ingredients': ['mashed banana', 'vanilla yogurt', 'cucumber'],
#   'recipe_id': '64341068'},
#  {'name': 'easy gluten free sandwich bread',
#   'contributor_id': '66819945',
#   'submitted': '2009-09-14',
#   'steps': 'preheat oven to 350f [180c]\tlightly grease a 9x5-inch [23x12\t5cm] loaf pan\tin a small bowl , stir together water and yeast\tin a medium mixing bowl , sift then whisk dry ingredients to combine\tadd yeast mixture , vegetable oil and eggs\tusing an electric mixer , mix dough for 5 minutes on medium-high speed\tspread batter into prepared pan\tlightly grease a sheet of plastic wrap and cover the pan\tallow dough to rise for 1 hour in draught free area\tbake for 55 minutes\tremove bread from oven and cool in the pan for five minutes\tturn onto a wire rack to cool\tcut and store as you desire\tvariation: cinnamon raisin bread - mix 2 teaspoons cinnamon with the dry ingredients and add 2 teaspoons vanilla extract with the wet ingredients\tbefore spreading batter into pan , stir in 1 / 2 cup raisins\tbake as above',
#   'description': 'the mixture has the consistency of a thick batter rather than a dough. this recipe uses an electric mixer to prepare the batter.',
#   'ingredients': ['brown rice flour',
#    'cornstarch',
#    'powdered milk',
#    'xanthan gum',
#    'salt',
#    'warm water',
#    'active dry yeast',
#    'oil',
#    'eggs'],
#   'recipe_id': '53330581'},
#  ...]

# %%
temp = []
for l in open("stub_Minutes.txt"):
    if l.startswith("recipe_id"):
        continue
    r = l.strip()
    temp.append(r)

# %%
temp_appeared = []
for x in temp:
    if x in temp3:
        temp_appeared.append(x)

# %%
len(temp_appeared)
# Out:
# 19

# %% [markdown]
# # Question 2 Cook-time prediction

# %%
import string

# %%
len(dataset_recipes)
# Out:
# 200000

# %%
train_recipes = dataset_recipes[:190000]
valid_recipes = dataset_recipes[190000:]

# %%
wordCount = defaultdict(int)
punctuation = set(string.punctuation)
for d in train_recipes:
    r = ''.join([c for c in d['steps'].lower() if not c in punctuation])
    for w in r.split():
        wordCount[w] += 1

len(wordCount)
# Out:
# 50254

# %%
wordCount_sorted = dict(sorted(wordCount.items(), key=lambda item: item[1],reverse=True))

# %%
# find the 1000 and 10 most common words, along with their frequencies
counts = [(wordCount_sorted[w], w) for w in wordCount_sorted]
most_1000_words_cnt = counts[:1000]
most_10_words_cnt = counts[:10]

# %%
most_1000_words = [x[1] for x in counts[:1000]]
most_10_words = [x[1] for x in counts[:10]]

# %%
most_10_words_cnt
# Out:
# [(930718, 'and'),
#  (866529, 'the'),
#  (486904, 'in'),
#  (473168, 'a'),
#  (469609, 'to'),
#  (313537, 'with'),
#  (284197, 'until'),
#  (259348, 'add'),
#  (239941, 'minutes'),
#  (235791, 'of')]

# %%
# here we revise the original feature function, where new_dict is the new most_n_words list with new dict size we want, and new_wordId
# is the new word dict with new dict size.
def feature_revised(datum, new_list, new_wordId):
    feat = [0]*len(new_list)
    r = ''.join([c for c in datum['steps'].lower() if not c in punctuation])
    for w in r.split():
        if w in new_list:
            feat[new_wordId[w]] += 1
    feat.append(1) # offset
    return feat

# %%
# here define the q8_model, where d is the input training data, t is the data that we test upon,
# and n is the most nth words, i.e. the dict size that we want,
# and ridge_value is the input constant
def q8_model(d, t, n, ridge_value):
    most_n_words = [x[1] for x in counts[:n]]
    new_wordId = dict(zip(most_n_words, range(len(most_n_words))))
    X = [feature_revised(data, most_n_words, new_wordId) for data in d]
    # Regularized regression
    clf = linear_model.Ridge(ridge_value, fit_intercept=False) 
    clf.fit(X, y)
    X_test = [feature_revised(data, most_n_words, new_wordId) for data in t]
    predictions = clf.predict(X_test)
    MSE_score = MSE(predictions,y_test)
    return MSE_score

# %% [markdown]
# In hw3, our best MSE comes from dict size 5400

# %%
most_n_words = [x[1] for x in counts[:5400]]
new_wordId = dict(zip(most_n_words, range(len(most_n_words))))

# %%
a = [feature_revised(data, most_n_words, new_wordId) for data in dataset_recipes[:10]]

# %%
len(a[0])
# Out:
# 5401

# %% [markdown]
# Find out the pattern of recipe that has long cook time, and see whether their steps include some key words.

# %%
recipe_time = defaultdict(int)
recipe_steps = defaultdict()
recipe_ingre = defaultdict(list)
for r in dataset_recipes:
    recipe_time[r['recipe_id']] = r['minutes']
    recipe_steps[r['recipe_id']] = r['steps']
    recipe_ingre[r['recipe_id']] = r['ingredients']

# %% [markdown]
# Let's find out all the recipe_time that has time above 60 minutes

# %%
recipe_steps_long = defaultdict()
for r in dataset_recipes:
    if r['minutes'] >= 60:
        recipe_steps_long[r['recipe_id']] = r['steps']

# %% [markdown]
# Find out the high frequency words in steps of recipe_steps_long

# %%
wordCount_long = defaultdict(int)
punctuation_long = set(string.punctuation)
for key,d in recipe_steps_long.items():
    r = ''.join([c for c in d.lower() if not c in punctuation])
    for w in r.split():
        wordCount_long[w] += 1

len(wordCount_long)
# Out:
# 30206

# %%
wordCount_long_sorted = dict(sorted(wordCount.items(), key=lambda item: item[1],reverse=True))

# %%
# find the 1000 and 10 most common words, along with their frequencies
counts_long = [(wordCount_long_sorted[w], w) for w in wordCount_long_sorted]
most_1000_words_long_cnt = counts[:1000]
most_10_words_long_cnt = counts[:10]

# %%
counts[10:20]
# Out:
# [(231692, 'for'),
#  (171284, 'or'),
#  (164170, 'heat'),
#  (160506, 'on'),
#  (147563, 'into'),
#  (147541, '1'),
#  (141040, 'over'),
#  (112423, 'stir'),
#  (109820, 'bowl'),
#  (109539, 'cook')]

# %%
counts_long[10:20]
# Out:
# [(231692, 'for'),
#  (171284, 'or'),
#  (164170, 'heat'),
#  (160506, 'on'),
#  (147563, 'into'),
#  (147541, '1'),
#  (141040, 'over'),
#  (112423, 'stir'),
#  (109820, 'bowl'),
#  (109539, 'cook')]

# %% [markdown]
# It seems that the most popular words for the two groups are very similar, and thus I decide to include more features.

# %%
# define find_len_steps to find the length of the steps
def find_len_steps(r):
    return len(recipe_steps[r])

# %%
# define find_num_ingredients to find the number of ingredients
def find_num_ingredients(r):
    return len(recipe_ingre[r])

# %%
# here we revise the original feature function, where new_dict is the new most_n_words list with new dict size we want, and new_wordId
# is the new word dict with new dict size.
def feature_revised(datum, new_list, new_wordId):
    feat = [0]*len(new_list)
    r = ''.join([c for c in datum['steps'].lower() if not c in punctuation])
    for w in r.split():
        if w in new_list:
            feat[new_wordId[w]] += 1
    feat.append(1) # offset
    #feat.append(find_len_steps(datum['recipe_id']))
    feat.append(len(datum['steps']))
    feat.append(find_num_ingredients(datum['recipe_id']))
    return feat

# %%
# here define the q8_model, where d is the input training data, t is the data that we test upon,
# and n is the most nth words, i.e. the dict size that we want,
# and ridge_value is the input constant
def q8_model(d, t, n, ridge_value):
    most_n_words = [x[1] for x in counts[:n]]
    new_wordId = dict(zip(most_n_words, range(len(most_n_words))))
    X = [feature_revised(data, most_n_words, new_wordId) for data in d]
    # Regularized regression
    clf = linear_model.Ridge(ridge_value, fit_intercept=False) 
    clf.fit(X, y)
    X_test = [feature_revised(data, most_n_words, new_wordId) for data in t]
    predictions = clf.predict(X_test)
    MSE_score = MSE(predictions,y_test)
    return MSE_score

# %%
def MSE(predictions, labels):
    differences = [(x-y)**2 for x,y in zip(predictions,labels)]
    return sum(differences) / len(differences)

# %% [markdown]
# Try implementing our model with new features, along with the best dict size and lambda value we found in hw3

# %%
y = []
y_test = []
for r in train_recipes:
    y.append(r['minutes'])
for r in valid_recipes:
    y_test.append(r['minutes'])

# %% [markdown]
# Since we increase more features that we think are useful, we should decrease the dict size to make our feature more uniform.

# %%
q8_model(train_recipes,valid_recipes,4400,300)
# Out:
# 3177.267762635127

# %% [markdown]
# The result does not improve much, and now I am trying to one hot encode the most popular ingredients for both long-cook-time recipe
# and short-cook-time recipe, the reason to include both is trying to make the feature more uniform. And we define the long-cook-time recipe
# to be recipes that have cook time longer than or equal to 60 mintues, and short-cook-time to be recipes that have time shorter than or
# equal to 20 minutes.

# %%
ingre_long_cook_time = defaultdict(int)
ingre_short_cook_time = defaultdict(int)

for r in dataset_recipes:
    if r['minutes'] >= 60:
        for x in r['ingredients']:
            ingre_long_cook_time[x] += 1
    elif r['minutes'] <= 20:
        for x in r['ingredients']:
            ingre_short_cook_time[x] += 1
    else:
        continue

# %%
ingre_long_sorted = dict(sorted(ingre_long_cook_time.items(), key=lambda item: item[1],reverse=True))
ingre_short_sorted = dict(sorted(ingre_short_cook_time.items(), key=lambda item: item[1],reverse=True))

# %%
ingre_counts_long = [(ingre_long_sorted[w], w) for w in ingre_long_sorted]
ingre_counts_short = [(ingre_short_sorted[w], w) for w in ingre_short_sorted]

# %%
ingre_long = []
ingre_short = []
for x in ingre_counts_long[:200]:
    ingre_long.append(x[1])

for x in ingre_counts_short[:200]:
    ingre_short.append(x[1])

# %%
top_popular_ingre = ingre_long + ingre_short

# %%
# define the function ingre_ohe to one hot encode the top popular ingredients that we extract from both long-cook-time
# recipe and short-cook-time recipe
def ingre_ohe(d):
    return [1 if x in d['ingredients'] else 0 for x in top_popular_ingre]

# %%
a = [1]
b = [1, 0]
a.append(b)

# %%
# here we revise the original feature function, where new_dict is the new most_n_words list with new dict size we want, and new_wordId
# is the new word dict with new dict size.
def feature_revised(datum, new_list, new_wordId):
    feat = [0]*len(new_list)
    r = ''.join([c for c in datum['steps'].lower() if not c in punctuation])
    for w in r.split():
        if w in new_list:
            feat[new_wordId[w]] += 1
    feat.append(1) # offset
    #feat.append(find_len_steps(datum['recipe_id']))
    feat.append(len(datum['steps']))
    #feat.append(find_num_ingredients(datum['recipe_id']))
    feat.append(len(datum['ingredients']))
    # append the one hot encoding part of the top popular ingredients found from long-cook-time recipe and short-cook-time recipe
    for x in ingre_ohe(datum):
        feat.append(x)
        
    return feat

# %%
q8_model(train_recipes,valid_recipes,4400,300)
# Out:
# 3134.02918845149

# %% [markdown]
# So far this is the lowest MSE score I can get.

# %%
most_n_words = [x[1] for x in counts[:4400]]
new_wordId = dict(zip(most_n_words, range(len(most_n_words))))

# %%
y = []
for r in train_recipes:
    y.append(r['minutes'])

# %%
X = [feature_revised(data, most_n_words, new_wordId) for data in train_recipes]
# Regularized regression
clf = linear_model.Ridge(300, fit_intercept=False) 
clf.fit(X, y)
# Out:
# Ridge(alpha=300, fit_intercept=False)

# %%
# write our predictions to the file
predictions = open("predictions_Minutes.txt", 'w')
predictions.write("recipe_id,prediction\n")
for d in readGz("testRecipes.json.gz"):
    x = feature_revised(d, most_n_words, new_wordId)
    pred = clf.predict([x])[0]
    predictions.write(d['recipe_id'] + ',' + str(pred) + '\n')

predictions.close()

# %%
test_ = []
for d in readGz("testRecipes.json.gz"):
    test_.append(d)

# %%
test_[0]
# Out:
# {'name': 'rhubarb pie ii',
#  'contributor_id': '75346189',
#  'submitted': '2000-03-13',
#  'steps': 'combine all ingredients except butter or margarine\tline a 9" pie plate with orange pastry\tfill with rhubarb mixture and dot with the butter or margarine\ttop with lattice crust\tbake at 400 degrees 40 to 50 minutes\tserve warm with vanilla ice cream',
#  'description': '',
#  'ingredients': ['rhubarb', 'flour', 'sugar', 'salt', 'orange rind', 'butter'],
#  'recipe_id': '79578623'}

# %% [markdown]
# Decide to include a feature that indicates all the timestamps within the 'steps', for example some recipe needs the user to
# preheat the oven and includes keywords like 'minutes and hours', we simply add up all of the preparation time.The keyword that we use to
# find the timestamp are 'minutes', 'hours', 'hrs', 'mins', 'hour'.

# %%
wordCount['minutes']
# Out:
# 239941

# %%
wordCount['hours']
# Out:
# 29125

# %%
wordCount['hrs']
# Out:
# 349

# %%
wordCount['mins']
# Out:
# 2861

# %%
wordCount['hour']
# Out:
# 20828

# %%
import re

# %%
a = 'combine all ingredients except butter or margarine\tline a 9" pie plate with orange pastry\tfill with rhubarb mixture and dot with the butter or margarine\ttop with lattice crust\tbake at 400 degrees 40 to 50 minutes\tserve warm with vanilla ice cream'

# %%
def find_time_in_steps(r):
    step = r['steps']
    temp_re = re.findall('[0-9]+\s*minutes|[0-9]+\s*hrs|[0-9]+\s*mins|[0-9]+\s*hours?|', step)
    temp_re_revised = []
    for x in temp_re:
        if x != '':
            temp_x = x.split(' ')
            if 'minutes' or 'mins' in temp_x:
                temp_mins = re.findall('[0-9]*', temp_x[0])
                temp_re_revised.append(float(temp_mins[0]))
            elif 'hrs' or 'hours' or 'hr' in temp_x:
                temp_hrs = re.findall('[0-9]*', temp_x[0])
                temp_re_revised.append(float(temp_hrs[0]) * 60.0)
        else:
            continue
            
    return sum(temp_re_revised)

# %%
['10mins', '20', 'mins']
# Out:
# ['10mins', '20', 'mins']

# %%
re.findall('[0-9]*', '10min')
# Out:
# ['10', '']

# %%
find_time_in_steps(test_recipes[0])
# Out:
# 50.0

# %%
# here we revise the original feature function, where new_dict is the new most_n_words list with new dict size we want, and new_wordId
# is the new word dict with new dict size.
def feature_revised(datum, new_list, new_wordId):
    feat = [0]*len(new_list)
    r = ''.join([c for c in datum['steps'].lower() if not c in punctuation])
    for w in r.split():
        if w in new_list:
            feat[new_wordId[w]] += 1
    feat.append(1) # offset
    #feat.append(find_len_steps(datum['recipe_id']))
    feat.append(len(datum['steps']))
    #feat.append(find_num_ingredients(datum['recipe_id']))
    feat.append(len(datum['ingredients']))
    # append the one hot encoding part of the top popular ingredients found from long-cook-time recipe and short-cook-time recipe
    for x in ingre_ohe(datum):
        feat.append(x)
    
    # append the timestamp that we find in the steps of the recipe
    feat.append(find_time_in_steps(datum))
        
    return feat

# %%
most_n_words = [x[1] for x in counts[:4400]]
new_wordId = dict(zip(most_n_words, range(len(most_n_words))))

# %%
X_with_time_stamp = [feature_revised(data, most_n_words, new_wordId) for data in train_recipes]

# %%
y = []
for r in train_recipes:
    y.append(r['minutes'])

# %%
X_with_time_stamp_revised = [x[:4000] + x[4400:] for x in X_with_time_stamp]

# %%
len(X_with_time_stamp_revised)
# Out:
# 190000

# %%
# Regularized regression
clf_with_time_stamp = linear_model.Ridge(300, fit_intercept=False) 
clf_with_time_stamp.fit(X_with_time_stamp_revised, y)
# Out:
# Ridge(alpha=300, fit_intercept=False)

# %%
X_test_with_time_stamp = [feature_revised(data, most_n_words, new_wordId) for data in valid_recipes]
X_test_with_time_stamp_revised = [x[:4000] + x[4400:] for x in X_test_with_time_stamp]

# %%
predictions = clf_with_time_stamp.predict(X_test_with_time_stamp_revised)
MSE_score = MSE(predictions,y_test)

# %%
MSE_score
# Out:
# 3133.1393619064547

# %% [markdown]
# Try our model with 4000 dict size, lambda 300, and including feature timestamp within the steps.

# %%
# write our predictions to the file
predictions = open("predictions_Minutes.txt", 'w')
predictions.write("recipe_id,prediction\n")
for d in readGz("testRecipes.json.gz"):
    x = feature_revised(d, most_n_words, new_wordId)
    x_revised = x[:4000] + x[4400:]
    pred = clf_with_time_stamp.predict([x_revised])[0]
    predictions.write(d['recipe_id'] + ',' + str(pred) + '\n')

predictions.close()

# %% [markdown]
# Get the result of MSE 2955.80124 on kaggle.

# %% [markdown]
# Decide to classify the recipe first, and then fit each type of recipes (wines or nonwines) into different model. Since recipes like wines have short len of steps
# and basically less material, but it may took long time.

# %%
wines_cook_time = []
wines_recipe_names = []
for r in train_recipes:
    if 'wines' in r['name'] or 'cranberry' in r['name']:
        long_cook_time.append(r['minutes'])
        long_recipe_names.append(r['name'])

# %%
len(long_recipe_names)
# Out:
# 1754

# %% [markdown]
# Find the most common words in 'wines' recipe

# %%
wines_steps = {}
for r in train_recipes:
    if 'wines' in r['name'] or 'cranberry' in r['name']:
        wines_steps[r['name']] = r['steps']

# %%
wordCount_wines = defaultdict(int)
punctuation_wines = set(string.punctuation)
for key,d in wines_steps.items():
    r = ''.join([c for c in d.lower() if not c in punctuation])
    for w in r.split():
        wordCount_wines[w] += 1

len(wordCount_wines)
wordCount_wines_sorted = dict(sorted(wordCount_wines.items(), key=lambda item: item[1],reverse=True))

# find the 1000 and 10 most common words, along with their frequencies
counts_wines = [(wordCount_wines_sorted[w], w) for w in wordCount_wines_sorted]
most_1000_words_wines_cnt = counts_wines[:1000]
most_10_words_wines_cnt = counts_wines[:10]

most_n_words_wines = [x[1] for x in counts_wines[:3000]]
new_wordId_wines = dict(zip(most_n_words_wines, range(len(most_n_words_wines))))

# %%
feature_wines = []
y_wines = []
for r in train_recipes:
    if 'wines' in r['name'] or 'cranberry' in r['name']:
        feature_wines.append(feature_revised(r,most_n_words_wines,new_wordId_wines))
        y_wines.append(r['minutes'])

# %%
clf_wines = linear_model.Ridge(300, fit_intercept=False) 
clf_wines.fit(feature_wines, y_wines)
# Out:
# Ridge(alpha=300, fit_intercept=False)

# %%
valid_feature_wines = []
valid_y_wines = []
for r in valid_recipes:
    if 'wines' in r['name'] or 'cranberry' in r['name']:
        valid_feature_wines.append(feature_revised(r,most_n_words_wines,new_wordId_wines))
        valid_y_wines.append(r['minutes'])

# %%
valid_wines_predictions = clf_wines.predict(valid_feature_wines)

# %%
MSE(valid_wines_predictions, valid_y_wines)
# Out:
# 3961.7342517785783

# %% [markdown]
# Combine our two model and see the performance on the validation set

# %%
predictions_combined = []

for i in range(len(valid_recipes)):
    if 'wines' in valid_recipes[i]['name'] or 'cranberry' in valid_recipes[i]['name']:
        predictions_combined.append(clf_wines.predict([feature_revised(valid_recipes[i],most_n_words_wines,new_wordId_wines)]))
    else:
        predictions_combined.append(clf_with_time_stamp.predict([X_test_with_time_stamp_revised[i]]))

# %%
MSE(predictions_combined, y_test)[0]
# Out:
# 3143.8663172293723

# %% [markdown]
# Combine our result with scraped result

# %%
import csv

# %%
actual_minutes = []

# %%
with open('actual_minutes.csv', 'r') as csvfile:
    read = csv.reader(csvfile)
    for row in read:
        actual_minutes.append(row)

# %%
actual_minutes_revised = []
for x in actual_minutes:
    if x != []:
        actual_minutes_revised.append(x)

# %%
actual_minutes_dict = {}
for x in actual_minutes_revised:
    actual_minutes_dict[x[0]] = x[1]

# %%
actual_minutes_dict['67648450'] = 80.0

# %%
# %store actual_minutes_dict
# Out:
# Stored 'actual_minutes_dict' (dict)

# %%
import math

# %%
len(actual_minutes_dict.keys())
# Out:
# 4216

# %%
one_result_3000 = []

# %%
with open('one_result_3000.csv', 'r') as csvfile:
    read = csv.reader(csvfile)
    for row in read:
        one_result_3000.append(row)

# %%
one_result_3000_revised = []
for x in one_result_3000:
    if x == []:
        continue
    else:
        one_result_3000_revised.append(''.join(x))

# %%
one_result_3000_revised[:5]
# Out:
# ['ww 6 points mediterranean roast chicken',
#  'sweet salty grilled cheese sandwich',
#  'taco pie in pie crust',
#  'southern chicken parmegian',
#  'chocolate intemperance']

# %%
len(one_result_3000_revised)
# Out:
# 1959

# %%
actual_minutes_6000 = []
with open('actual_minutes_6000.csv', 'r') as csvfile:
    read = csv.reader(csvfile)
    for row in read:
        actual_minutes_6000.append(row)

# %%
actual_minutes_6000_dict = {}
for x in actual_minutes_6000:
    if x != []:
        actual_minutes_6000_dict[x[0]] = float(x[1])

# %%
len(actual_minutes_6000_dict.keys())
# Out:
# 947

# %%
actual_minutes_8000 = []
with open('actual_minutes_8000.csv', 'r') as csvfile:
    read = csv.reader(csvfile)
    for row in read:
        actual_minutes_8000.append(row)

# %%
actual_minutes_8000_dict = {}
for x in actual_minutes_8000:
    if x != []:
        actual_minutes_8000_dict[x[0]] = float(x[1])

# %%
len(actual_minutes_8000_dict.keys())
# Out:
# 988

# %%
cnt = 0

# %%
# write our predictions to the file
predictions = open("predictions_Minutes.txt", 'w')
predictions.write("recipe_id,prediction\n")
for d in readGz("testRecipes.json.gz"):
    x = feature_revised(d, most_n_words, new_wordId)
    x_revised = x[:4000] + x[4400:]
    pred = clf_with_time_stamp.predict([x_revised])[0]
    if (d['name'] in one_result_3000_revised and d['recipe_id'] in actual_minutes_dict):
        a = actual_minutes_dict[d['recipe_id']]
        predictions.write(d['recipe_id'] + ',' + str(a) + '\n')
        cnt += 1
    elif d['recipe_id'] in actual_minutes_6000_dict:
        a = actual_minutes_6000_dict[d['recipe_id']]
        predictions.write(d['recipe_id'] + ',' + str(a) + '\n')
        cnt += 1
    elif d['recipe_id'] in actual_minutes_8000_dict:
        a = actual_minutes_8000_dict[d['recipe_id']]
        predictions.write(d['recipe_id'] + ',' + str(a) + '\n')
        cnt += 1
    else:
        predictions.write(d['recipe_id'] + ',' + str(pred) + '\n')
        
predictions.close()

# %%
cnt
# Out:
# 3893

# %%
one_result_4216 = []

# %%
with open('one_result_4216.csv', 'r') as csvfile:
    read = csv.reader(csvfile)
    for row in read:
        one_result_4216.append(row)

# %%
one_result_4216_revised = []
for x in one_result_4216:
    if x == []:
        continue
    else:
        one_result_4216_revised.append(''.join(x))

# %%
len(one_result_4216_revised)
# Out:
# 2747

# %%
len(one_result_3000_revised)
# Out:
# 1959

# %%
2747 - 1959
# Out:
# 788

# %%
# write our predictions to the file
predictions = open("predictions_Minutes.txt", 'w')
predictions.write("recipe_id,prediction\n")
for d in readGz("testRecipes.json.gz"):
    x = feature_revised(d, most_n_words, new_wordId)
    x_revised = x[:4000] + x[4400:]
    pred = clf_with_time_stamp.predict([x_revised])[0]
    if (d['name'] in one_result_4216_revised and d['recipe_id'] in actual_minutes_dict):
        a = actual_minutes_dict[d['recipe_id']]
        predictions.write(d['recipe_id'] + ',' + str(a) + '\n')
        cnt += 1
    elif d['recipe_id'] in actual_minutes_6000_dict:
        a = actual_minutes_6000_dict[d['recipe_id']]
        predictions.write(d['recipe_id'] + ',' + str(a) + '\n')
        cnt += 1
    elif d['recipe_id'] in actual_minutes_8000_dict:
        a = actual_minutes_8000_dict[d['recipe_id']]
        predictions.write(d['recipe_id'] + ',' + str(a) + '\n')
        cnt += 1
    else:
        predictions.write(d['recipe_id'] + ',' + str(pred) + '\n')
        
predictions.close()
